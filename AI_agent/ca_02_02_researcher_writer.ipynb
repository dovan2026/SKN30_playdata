# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
from crewai import Agent, Task, Crew, Process

# %% [markdown]
# ### 1.에이전트 정의 (연구원, 작가 역할)

# %%
researcher = Agent(
    role='AI Researcher',
    goal='멀티 에이전트 시스템의 주요 장법을 3가지 조사하여 설명합니다.',
    backstory='다년간 AI 트렌드를 연구해온 전문가입니다.',
    llm='openai/gpt-4.1-mini',           # gpt-4o-mini가 CoT, ToT 이런 걸 잘 못함.
     # tools = [web_search]
)

writer = Agent(
    role = 'Technical Writer',
    goal = '연구 결과를 바탕으로 간략한 결론을 작성합니다.',
    backstory = '복잡한 정보를 쉽게 요약하는 작문 전문가입니다.',
    llm = 'openai/gpt-4.1-mini'
)

# %% [markdown]
# ### 2.태스크 정의 (조사 태스크, 작성 태스크)

# %%
researcher_task = Task(
    description = '멀티 에이전트 시스템의 주요 장점 3가지를 조사하고, 각 장점을 간략히 설명하세요.',
    expected_output = '3가지 장점에 대한 간단한 설명 (bullet point 목록)',
    agent = researcher
)

writer_task = Task(
    description = '위 조사 결과를 참고하여, 멀티 에이전트 시스템의 장점에 대한 짧은 결론을 작성하세요.',
    expected_output = '3~4문장으로 구성된 결론 단락',
    agent = writer,
    context=[researcher_task]       # 이전 태스크의 결과를 활용. process=Procoess.sequential일 때 생략 가능. 생략하는 게 좋은 습관은 아님.
)

# %% [markdown]
# ### 3.Crew 생성 (에이전트 팀 구성 및 프로세스 설정)

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[researcher_task, writer_task],
    process=Process.sequential,         # process는 task 연관되어 있음.
    verbose=True
)

# %% [markdown]
# ### 4.크루 실행 및 결과 출력

# %%
crew_output = await crew.kickoff_async()
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 47bdb5ff-a600-47fe-b72d-600ad6a3582a                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 멀티 에이전트 시스템의 주요 장점 3가지를 조사하고, 각 장점을 간략히 설명하세요.                          │
# │  ID: 160d9006-141e-4bb9-962a-9897b107db7b                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: AI Researcher                                                                                           │
# │                                                                                                                 │
# │  Task: 멀티 에이전트 시스템의 주요 장점 3가지를 조사하고, 각 장점을 간략히 설명하세요.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: AI Researcher                                                                                           │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  - **분산 처리 및 병렬성 향상**: 멀티 에이전트 시스템은 여러 에이전트가 동시에 작업을 수행함으로써 문제 해결    │
# │  속도를 높이고 대규모 문제도 효율적으로 처리할 수 있습니다.                                                     │
# │                                                                                                                 │
# │  - **유연성과 적응성**: 각 에이전트는 독립적으로 동작하면서 환경 변화에 신속하게 대응할 수 있어, 시스템 전체가  │
# │  변화하는 상황에 적응하는 데 강점을 가집니다.                                                                   │
# │                                                                                                                 │
# │  - **확장성 및 모듈성**: 새로운 에이전트를 추가하거나 제거하는 것이 용이하여 시스템을 쉽게 확장하거나 수정할    │
# │  수 있으며, 문제를 작은 단위로 분할해 관리하기 편리합니다.                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 멀티 에이전트 시스템의 주요 장점 3가지를 조사하고, 각 장점을 간략히 설명하세요.                          │
# │  Agent: AI Researcher                                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 위 조사 결과를 참고하여, 멀티 에이전트 시스템의 장점에 대한 짧은 결론을 작성하세요.                      │
# │  ID: f5e2e28c-6966-4731-8655-b25761214610                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technical Writer                                                                                        │
# │                                                                                                                 │
# │  Task: 위 조사 결과를 참고하여, 멀티 에이전트 시스템의 장점에 대한 짧은 결론을 작성하세요.                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technical Writer                                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  멀티 에이전트 시스템은 분산 처리와 병렬성을 통해 문제 해결 속도를 크게 향상시킬 수 있습니다. 또한, 각          │
# │  에이전트의 독립적인 동작으로 유연성과 적응성이 뛰어나 변화하는 환경에도 효과적으로 대응할 수 있습니다. 더불어  │
# │  확장성과 모듈성이 뛰어나 시스템 확장 및 관리를 용이하게 합니다. 이러한 장점들로 인해 멀티 에이전트 시스템은    │
# │  복잡한 문제 해결에 매우 효과적인 접근법이라 할 수 있습니다.                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 위 조사 결과를 참고하여, 멀티 에이전트 시스템의 장점에 대한 짧은 결론을 작성하세요.                      │
# │  Agent: Technical Writer                                                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 47bdb5ff-a600-47fe-b72d-600ad6a3582a                                                                       │
# │  Final Output: 멀티 에이전트 시스템은 분산 처리와 병렬성을 통해 문제 해결 속도를 크게 향상시킬 수 있습니다.     │
# │  또한, 각 에이전트의 독립적인 동작으로 유연성과 적응성이 뛰어나 변화하는 환경에도 효과적으로 대응할 수          │
# │  있습니다. 더불어 확장성과 모듈성이 뛰어나 시스템 확장 및 관리를 용이하게 합니다. 이러한 장점들로 인해 멀티     │
# │  에이전트 시스템은 복잡한 문제 해결에 매우 효과적인 접근법이라 할 수 있습니다.                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### 5.각 태스크의 결과를 순차적으로 출력

# %%
for idx, task_output in enumerate(crew_output.tasks_output, start=1):
    print(f"\n[Task {idx} Output]\n{task_output}\n")
# Out:
# [Task 1 Output]
# - **분산 처리 및 병렬성 향상**: 멀티 에이전트 시스템은 여러 에이전트가 동시에 작업을 수행함으로써 문제 해결 속도를 높이고 대규모 문제도 효율적으로 처리할 수 있습니다.
#
# - **유연성과 적응성**: 각 에이전트는 독립적으로 동작하면서 환경 변화에 신속하게 대응할 수 있어, 시스템 전체가 변화하는 상황에 적응하는 데 강점을 가집니다.
#
# - **확장성 및 모듈성**: 새로운 에이전트를 추가하거나 제거하는 것이 용이하여 시스템을 쉽게 확장하거나 수정할 수 있으며, 문제를 작은 단위로 분할해 관리하기 편리합니다.
#
#
# [Task 2 Output]
# 멀티 에이전트 시스템은 분산 처리와 병렬성을 통해 문제 해결 속도를 크게 향상시킬 수 있습니다. 또한, 각 에이전트의 독립적인 동작으로 유연성과 적응성이 뛰어나 변화하는 환경에도 효과적으로 대응할 수 있습니다. 더불어 확장성과 모듈성이 뛰어나 시스템 확장 및 관리를 용이하게 합니다. 이러한 장점들로 인해 멀티 에이전트 시스템은 복잡한 문제 해결에 매우 효과적인 접근법이라 할 수 있습니다.

# %%
import crewai
print(crewai.__version__)
# Out:
# 1.14.7
