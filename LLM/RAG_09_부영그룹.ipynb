# %% [markdown]
# # 1. LOAD

# %%
from langchain_community.document_loaders import PyPDFLoader

# PDF 파일 처리
pdf_path = "data2/부영그룹.pdf"  # PDF 파일 경로 입력
loader = PyPDFLoader(pdf_path)  # PDF 파일 읽기
documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 9.9', 'creator': 'Adobe InDesign CS5 (7.0)', 'creationdate': '2024-02-29T17:43:53+09:00', 'moddate': '2024-02-29T17:43:53+09:00', 'source': 'data2/부영그룹.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='17Ins I ght Korea ˚ March 2024\n한 직원자녀 70여명에게 직접적 인 경제지원이 이뤄지도\n록 출산장려금 1억원씩 총 70억원을 지급키로 했다”고 \n밝혔다. \n출산장려금을 지급하는 회사들은 종종 있어왔지만 지원\n금이 억대에 이르는 경우는 부영그룹이 최초다. \n이를 두고 일각에서는 기업 형편에 비해 과도한 복지로 \n재무부담을 키우는 것 아니냐는 우려도 제기된다. 부영\n그룹은 부동산 시장 침체로 인해서 시공능력순위가 1년 \n사이에 35위에서 93위로 급락했다. 주력 사업인 주택부\n문 매출액이 급감한 여파다. 지난 2022년 기준 부영그룹\n의 매출액은 5564억원, 영업손실 1615억원을 기록했다. \n1년 사이에 매출액은 62,7% 줄어들고, 영업손실이 늘어\n난 것이다. 부영그룹 산하 계열사들의 재무건전성에도 비\n상등이 켜졌다. 부영주택과 동광주택산업의 부채비율은 \n각각 437%, 330%에 이른다. 남광건설산업과 남양개발\n도 적자 누적으로 자본잠식에 빠진 상태다.\n문제는 이렇다 할 신수종 사업이 없다는 점이다. 포트폴\n리오 다각화를 위해서 리조트 등 관광부문을 키우려고 \n하지만 신통치 않은 상태다. 올해도 주택시장이 좋지 않\n을 것으로 예상되는 가운데, 실적을 견인할 비전이 부족\n한 상황에서 출산장려금 선심보다 내실다지기가 우선돼\n야 하는 것 아니냐는 지적이다.  \n이번 부영의 출산장려금에는 조세 문제가 뜨거운 감자로 \n떠오르면서 이와 관련한 논의도 진행되고 있다. 이에 대\n한 논의가 잘 이뤄질 경우 부영그룹의 선례가 남아 향후 \n다른 기업들의 출산장려금에도 적용될 수 있을 것으로 \n전망된다. \n부영그룹이 쏘아올린 ‘세제 혜택’ 이슈 \n부영그룹은 출산장려금 1억원을 지원할 때 ‘직원’이 아닌 \n‘자녀’에게 증여하는 방법을 선택했다. 이로 인해 출산장\n려금을 근로소득으로 봐야하느냐, 증여로 봐야하느냐 \n하는 논쟁이 불거졌다. \n현재 근로소득 과세표준 구간을 보면 ▲1400만원 이하 \n6% ▲1400만원 초과~5000만원 이하 15% ▲5000만원 \n초과 8800만원 이하 24% ▲8800만원 초과 1억5000만\n원 이하 35% ▲1억5000만원 초과 3억 이하 38% 등으로 \n구간이 나눠져 있다. 출산장려금 1억원이 근로소득으로 \n들어갈 경우 직원들의 연봉과 더해져 세후 실수령 액은 \n대폭 줄어들 것으로 예상된다. \n반면에 증여로 인정될 경우 1억원 이하 증여에 대한 세율 \n10%만 적용된다. 직원 입장에서 세부담이 크게 줄어드\n는 셈이다.\n이에 이 회장은 지난 2월 19일 이기일 보건복지부 제1차\n관을 만나 출산장려금을 지원하게 된 계기를 설명하고 \n이에 대한 면세 혜택 도입을 당부했다.\n정부 역시도 출산장려금이 저출산 대책인 것을 고려해 \n긍정적인 방향으로 검토하고 있는 것으로 알려졌다. \n2월 5일 서울시 중구에 위치한 부영태평빌딩 \n컨벤션홀에서 열린 2024년 시무식 후 \n출산장려금을 받은 임직원들이 기념촬영을 하고 \n있다.<인사이트코리아>\n부영그룹은 2021년 이후 \n출산한 직원들에게 \n인원제한 없이 아이를 \n낳을 때마다 일시불로 \n1억원을 지원한다고 밝혔다. \n더불어 셋째까지 출산하는 \n가정의 경우 3억원 또는 \n영구임대주택을 제공할 \n예정이라고 덧붙였다.')]

# %%
from langchain_community.document_loaders import WebBaseLoader

website_loader = WebBaseLoader("https://n.news.naver.com/article/437/0000378416")
website_documents = website_loader.load()
print(website_documents)
# Out:
# [Document(metadata={'source': 'https://n.news.naver.com/article/437/0000378416', 'title': "출산 직원에게 '1억원' 쏜다…회사의 파격적 저출생 정책", 'language': 'ko'}, page_content='\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n출산 직원에게 \'1억원\' 쏜다…회사의 파격적 저출생 정책\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n본문 바로가기\n\n\n\n\n\n\n이전 페이지\n\n\n\n\n\n\n\n\n\n\nJTBC\n\n\n\n\n\n구독\n\n메인 뉴스판에서 JTBC 주요뉴스를 볼 수 있습니다.\n보러가기\n닫기\n\n\nJTBC 언론사 구독 해지되었습니다.\n닫기\n\n\n\n\n\n\n\n\n\n\n주요뉴스\n이슈\n정치\n경제\n사회\n생활\n세계\n저녁방송\n생중계\n클립\n랭킹\n\n\n\nMY\n\n\n뉴스 이용 설정을 할 수 있어요\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJTBC\n\n\n\nPICK\n안내\n\n\n언론사가 주요기사로선정한 기사입니다.\n언론사별 바로가기\n닫기\n\n\n\n\n출산 직원에게 \'1억원\' 쏜다…회사의 파격적 저출생 정책\n\n\n\n\n\n\n이상화 기자\n\n\n\n\n\n이상화 기자\n\n\n\n\n\n\n입력\n2024.02.05. 오후 8:39\n\n\n\n기사원문\n \n\n\n\n\n\n\n\n\n\n\n추천\n반응\n\n\n\n\n쏠쏠정보\n0\n\n\n\n\n흥미진진\n0\n\n\n\n\n공감백배\n0\n\n\n\n\n분석탁월\n0\n\n\n\n\n후속강추\n0\n\n\n \n\n\n\n\n댓글\n반응\n\n\n\n\n\n\n\n\n텍스트 음성 변환 서비스 사용하기\n\n\n\n성별\n남성\n여성\n\n\n말하기 속도\n느림\n보통\n빠름\n\n이동 통신망을 이용하여 음성을 재생하면 별도의 데이터 통화료가 부과될 수 있습니다.\n본문듣기 시작\n\n닫기\n\n\n \n\n글자 크기 변경하기\n\n글자크기\n\n\n가1단계\n작게\n\n\n가2단계\n보통\n\n\n가3단계\n크게\n\n\n가4단계\n아주크게\n\n\n가5단계\n최대크게\n\n\n닫기\n\n\n\n\nSNS 보내기\n\n\n\n인쇄하기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n[앵커]올해 아이 낳을 계획이 있는 가족이라면 솔깃할 소식입니다. 정부가 저출생 대책으로 매달 주는 부모 급여, 0세 아이는 100만원으로 올렸습니다. 여기에 첫만남이용권, 아동수당까지 더하면 아이 돌까지 1년 동안 1520만원을 받습니다. 지자체도 경쟁하듯 지원에 나섰습니다. 인천시는 새로 태어난 아기, 18살될 때까지 1억원을 주겠다. 광주시도 17살될 때까지 7400만원 주겠다고 했습니다. 선거 때면 나타나서 아이 낳으면 현금 주겠다고 밝힌 사람이 있었죠. 과거에는 표만 노린 \'황당 공약\'이라는 비판이 따라다녔습니다. 그런데 지금은 출산율이 이보다 더 나쁠 수 없다보니, 이런 현금성 지원을 진지하게 정책화 하는 상황까지 온 겁니다. 게다가 기업들도 뛰어들고 있습니다. 이번에는 출산한 직원에게 단번에 1억원을 주겠다는 회사까지 나타났습니다.이상화 기자가 취재했습니다.[기자]한 그룹사가 오늘 파격적인 저출생 정책을 내놨습니다.2021년 이후 태어난 직원 자녀에 1억원씩, 총 70억원을 지원하고 앞으로도 이 정책을 이어가기로 했습니다.해당 기간에 연년생과 쌍둥이 자녀가 있으면 총 2억원을 받게 됩니다.[오현석/부영그룹 직원 : 아이 키우는 데 금전적으로 많이 힘든 세상이잖아요. 교육이나 생활하는 데 큰 도움이 될 거라 생각합니다.]만약 셋째까지 낳는 경우엔 국민주택을 제공하겠다는 뜻도 밝혔습니다.[이중근/부영그룹 회장 : 3년 이내에 세 아이를 갖는 분이 나올 것이고 따라서 주택을 제공할 수 있는 계기가 될 것으로 생각하고.][조용현/부영그룹 직원 : 와이프가 셋째도 갖고 싶어 했는데 경제적 부담 때문에 부정적이었거든요. (이제) 긍정적으로 생각할 수 있을 것 같습니다.]오늘 행사에서는, 회사가 제공하는 출산장려금은 받는 직원들의 세금 부담을 고려해 정부가 면세해달라는 제안도 나왔습니다.이같은 출산장려책은 점점 확산하는 분위기입니다.법정기간보다 육아휴직을 길게 주거나, 남성 직원의 육아휴직을 의무화한 곳도 있습니다.사내 어린이집을 밤 10시까지 운영하고 셋째를 낳으면 무조건 승진시켜 주기도 합니다.한 회사는 지난해 네쌍둥이를 낳은 직원에 의료비를 지원해 관심을 모았습니다.정부 대신 회사가 나서는 출산장려책이 사회적 분위기를 바꿀 거라는 기대가 커지는 가운데, 여력이 부족한 중소지원이 필요하다는 목소리도 나옵니다.[영상디자인 곽세미]\n\t\t\n\n\n\n이상화 기자 (sh9989@jtbc.co.kr) [영상취재: 유연경 / 영상편집: 류효정]\n\n\n\n\nCopyright ⓒ JTBC. All rights reserved. 무단 전재 및 재배포 금지.\n\n \n이 기사는 언론사에서 경제 섹션으로 분류했습니다.\n\n기사 섹션 분류 안내\n기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. 언론사는 개별 기사를 2개 이상 섹션으로 중복 분류할 수 있습니다.\n닫기\n\n\n\n\n기자 프로필\n\n\n\n\n\n\n\n\n\n\n\n\n이상화 기자\n\n\n\n\n\n\n\n이상화 기자\n\n\n\nJTBC\n\n\n\n\n구독\n\n\n구독중\n\n\n\n\n\n\n\n\n\'규제\'가 터준 길 독주한 \'유통 공룡\'…\'탈팡이 쉽나\' 안하무인\n\n\n환율 1435원, 사흘째 하락했지만 외환위기 이후 연고점 최고기록될 듯\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n구독\nJTBC 구독하고 메인에서 바로 만나보세요!구독하고 메인에서 만나보세요!\n\n\n구독중\n언론사의 주요 뉴스를 메인에서 바로 만나보세요!주요 뉴스를 메인에서 만나보세요!\n\n\n언론사홈\n\n\n\n\n\n\nJTBC\n\n\t\t\t주요뉴스해당 언론사에서 선정하며 언론사(아웃링크)로 이동합니다.\n\n\n잘 만났다 요르단! 조별리그와 달라진 한국, 핵심은\n\'날강두 된\' 메시? 노쇼 논란…홍콩 정부까지 뿔났다\n필리핀 여성 흉내를…먹방 유튜버가 올린 영상 봤더니\n미성년 성착취 창구된 SNS…"당장 해법 마련 안해?"\n지하철서 고글끼고 손가락 이리저리 \'뭐 하는 거지?\'\n\n\n\n\n\n\n▶한없이 가벼운 정치 토크쇼 \'장르만 여의도\'\n\n\n\n\n▶트렌드뉴스부터 심층취재까지! 연재 더보기\n\n\n\n\n\n\n\n\n\n\n\nJTBC 언론사가 직접 선정한 이슈\n\t\t\t\n\n\n\n\n\n\n\n\n이슈\n2026 북중미 월드컵\n\n\n\n잉글랜드 : 크로아티아  하이라이트…2026 북중미 월드컵 조별리그 1차전\n\n\n\n\n\n\n\n\n\n\n이슈\n이재명 정부\n\n\n\n이 대통령 "트럼프와 골프 함께하기로 약속…90분간 깊은 얘기"\n\n\n\n\n\n\n\n\n\n\n이슈\n중동 전쟁\n\n\n\n미, 종전 MOU 첫 공개…백악관 "트럼프, 서명 마쳤다"\n\n\n\n동영상 뉴스\n\n\n\n\n\n\n\n이슈\n6·3 지방선거\n\n\n\n투표용지 1장당 25~75원 \'고무줄\'…지역별 인쇄비 천차만별\n\n\n\n\n\n\n\n\n\n\n이슈\n논란의 쿠팡\n\n\n\n\'역대급 과징금\' 쿠팡 "행정법원에 구제 신청" 미 증권거래위에 즉시 공시\n\n\n\n\n\n\n\n\n\n\n\n이전\n\n\n다음\n\n\n\n\n\n\n\n\n\n\n이 기사를 추천합니다\n\n\n기사 추천은 24시간 내 50회까지 참여할 수 있습니다.\n닫기\n\n\n\n\n\n\n쏠쏠정보\n0\n\n\n\n\n흥미진진\n0\n\n\n\n\n공감백배\n0\n\n\n\n\n분석탁월\n0\n\n\n\n\n후속강추\n0\n\n\n \n\n\n\n\n\n\n \n\n\n\n\n\n기자 구독 후 기사보기\n\n\n\n구독 없이 계속 보기\n\n\n\n\n\ ...

# %% [markdown]
# # 2. SPLIT

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 텍스트 분할
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,   # 청크의 최대 크기, 예)GPT-4의 입력 토큰 한계(8100~32000 토큰). 문자 수 기준
    chunk_overlap=50  # 청크 사이의 중복 정도. 청큰 간 겹침(문맥 보존)
)

texts = text_splitter.split_documents(documents)
print(f"총 {len(texts)}개의 텍스트 청크로 분할되었습니다.")
# Out:
# 총 4개의 텍스트 청크로 분할되었습니다.

# %% [markdown]
# # 3. EMBED, STORE

# %%
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from dotenv import load_dotenv
import os

load_dotenv()

# 벡터 스토어 생성
# 텍스트를 OpenAI용 벡터로 변환합니다.
embeddings = OpenAIEmbeddings()

# FAISS가 벡터를 받아 인덱스를 만들고 빠르게 검색할 수 있도록 준비
vectorstore = FAISS.from_documents(texts, embeddings)

# %% [markdown]
# # 4. Question

# %%
# 질문
question = "부영그룹에서 제공하는 직원 혜택은?"

# %% [markdown]
# # 5. RETRIEVE

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough

# 리트리버 설정
retriever = vectorstore.as_retriever(search_kwargs={"k": 2})

# OpenAI 모델 설정 (LLM)
llm = ChatOpenAI(
    model="gpt-4.1-mini",  # 사용할 모델 이름
    temperature=0,         # 생성된 답변의 일관성을 높이기 위해 temperature=0으로 설정
)

# 프롬프트 생성
prompt = PromptTemplate.from_template(
    """다음 반환된 맥락을 사용하여 질문에 답하세요.
맥락에서 정보를 못 찾으면 모른다고 말하세요.
한국어로 답하세요.

#Question: {question}
#Context: {context}
#Answer:"""
)


def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# 체인(chain) 생성
qa_chain = (
    {
        'context':retriever | format_docs,
        'question':RunnablePassthrough() # 입력 질문을 그대로 question 변수에 넣겠다.
    }
    | prompt
    | llm
    | StrOutputParser()
    ) # 체인끼리는 자유롭게 묶는 것이 가능하다. 순서만 지키면 됨.

# %% [markdown]
# # 6. ANSWER

# %%
def ask_rag(question):
    source_documents = retriever.invoke(question)
    answer = qa_chain.invoke(question)
    return {
        "result": answer,
        "source_documents": source_documents,
    }

# 질문-답변 실행
results = ask_rag(question)

# 결과 출력
print("### 답변 ###")
print(results["result"])

print("\n### 출처 문서 ###")
for doc in results["source_documents"]:
    print(f"출처: {doc.metadata.get('source', 'N/A')}")
    print(f"내용: {doc.page_content[:200]}...\n")  # 문서 내용 일부 출력
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 15
#      11         "source_documents": source_documents,
#      12     }
#      13
#      14 # 질문-답변 실행
# ---> 15 results = ask_rag(question)
#      16
#      17 # 결과 출력
#      18 print("### 답변 ###")
#
# Cell In[18], line 3, in ask_rag(question)
#       1 def ask_rag(question):
#       2     source_documents = retriever.invoke(question)
# ----> 3     answer = qa_chain.invoke(
#       4         {
#       5             "question": question,
#       6             "context": format_docs(source_documents),
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_core\runnables\base.py:3442, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3440 with set_config_context(config) as context:
#    3441     if i == 0:
# -> 3442         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3443     else:
#    3444         input_ = context.run(step.invoke, input_, config)
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_core\runnables\base.py:4175, in RunnableParallel.invoke(self, input, config, **kwargs)
#    4169     with get_executor_for_config(config) as executor:
#    4170         futures = [
#    4171             executor.submit(_invoke_step, step, input, config, key)
#    4172             for key, step in steps.items()
#    4173         ]
#    4174         output = {
# -> 4175             key: future.result()
#    4176             for key, future in zip(steps, futures, strict=False)
#    4177         }
#    4178 # finish the root run
#    4179 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_core\runnables\base.py:4158, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    4152 child_config = patch_config(
#    4153     config,
#    4154     # mark each step as a child run
#    4155     callbacks=run_manager.get_child(f"map:key:{key}"),
#    4156 )
#    4157 with set_config_context(child_config) as context:
# -> 4158     return context.run(
#    4159         step.invoke,
#    4160         input_,
#    4161         child_config,
#    4162     )
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_core\runnables\base.py:3442, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3440 with set_config_context(config) as context:
#    3441     if i == 0:
# -> 3442         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3443     else:
#    3444         input_ = context.run(step.invoke, input_, config)
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_core\retrievers.py:222, in BaseRetriever.invoke(self, input, config, **kwargs)
#     220 kwargs_ = kwargs if self._expects_other_args else {}
#     221 if self._new_arg_supported:
# --> 222     result = self._get_relevant_documents(
#     223         input, run_manager=run_manager, **kwargs_
#     224     )
#     225 else:
#     226     result = self._get_relevant_documents(input, **kwargs_)
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_core\vectorstores\base.py:1045, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1043 kwargs_ = self.search_kwargs | kwargs
#    1044 if self.search_type == "similarity":
# -> 1045     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1046 elif self.search_type == "similarity_score_threshold":
#    1047     docs_and_similarities = (
#    1048         self.vectorstore.similarity_search_with_relevance_scores(
#    1049             query, **kwargs_
#    1050         )
#    1051     )
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:643, in FAISS.similarity_search(self, query, k, filter, fetch_k, **kwargs)
#     623 def similarity_search(
#     624     self,
#     625     query: str,
#    (...)    629     **kwargs: Any,
#     630 ) -> List[Document]:
#     631     """Return docs most similar to query.
#     632
#     633     Args:
#    (...)    641         List of Documents most similar to the query.
#     642     """
# --> 643     docs_and_scores = self.similarity_search_with_score(
#     644         query, k, filter=filter, fetch_k=fetch_k, **kwargs
#     645     )
#     646     return [doc for doc, _ in docs_and_scores]
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:515, in FAISS.similarity_search_with_score(self, query, k, filter, fetch_k, **kwargs)
#     491 def similarity_search_with_score(
#     492     self,
#     493     query: str,
#    (...)    497     **kwargs: Any,
#     498 ) -> List[Tuple[Document, float]]:
#     499     """Return docs most similar to query.
#     500
#     501     Args:
#    (...)    513         L2 distance in float. Lower score represents more similarity.
#     514     """
# --> 515     embedding = self._embed_query(query)
#     516     docs = self.similarity_search_with_score_by_vector(
#     517         embedding,
#     518         k,
#    (...)    521         **kwargs,
#     522     )
#     523     return docs
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:266, in FAISS._embed_query(self, text)
#     264 def _embed_query(self, text: str) -> List[float]:
#     265     if isinstance(self.embedding_function, Embeddings):
# --> 266         return self.embedding_function.embed_query(text)
#     267     else:
#     268         return self.embedding_function(text)
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:805, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     795 """Call out to OpenAI's embedding endpoint for embedding query text.
#     796
#     797 Args:
#    (...)    802     Embedding for the text.
#     803 """
#     804 self._ensure_sync_client_available()
# --> 805 return self.embed_documents([text], **kwargs)[0]
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:599, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     597 _chunk_size = chunk_size or self.chunk_size
#     598 client_kwargs = {**self._invocation_params, **kwargs}
# --> 599 _iter, tokens, indices, token_counts = self._tokenize(texts, _chunk_size)
#     600 batched_embeddings: list[list[float]] = []
#     602 # Process in batches respecting the token limit
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:554, in OpenAIEmbeddings._tokenize(self, texts, chunk_size)
#     552     token = encoding.encode(text, **encoder_kwargs)
#     553 else:
# --> 554     token = encoding.encode_ordinary(text)
#     556 # Split tokens into chunks respecting the embedding_ctx_length
#     557 for j in range(0, len(token), self.embedding_ctx_length):
#
# File c:\Users\playdata2\work_space(playdata)\SKN30_playdata\LLM\.venv\Lib\site-packages\tiktoken\core.py:76, in Encoding.encode_ordinary(self, text)
#      67 """Encodes a string into tokens, ignoring special tokens.
#      68
#      69 This is equivalent to `encode(text, disallowed_special=())` (but slightly faster).
#    (...)     73 [31373, 995]
#      74 """
#      75 try:
# ---> 76     return self._core_bpe.encode_ordinary(text)
#      77 except UnicodeEncodeError:
#      78     # See comment in encode
#      79     text = text.encode("utf-16", "surrogatepass").decode("utf-16", "replace")
#
# TypeError: argument 'text': 'dict' object is not an instance of 'str'
