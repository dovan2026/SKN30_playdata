# %% [markdown]
# # 1.빈도수 분석
# - 빈도수 분석은 텍스트 데이터에서 특정 단어나 표현이 얼마나 자주 등장하는지를 세어 단어의 중요도와 패턴을 파악하는 방법이다.
# - 이 분석은 텍스트 데이터의 기본적이면서도 매우 중요한 분석 기법이다.
# - 단어 또는 표현이 등장한 횟수(Frequency)를 세어 가장 자주 등장하는 단어가 무엇인지 파악한다.
# 이를 통해 문서의 주제, 관심사, 주요 키워드를 알 수 있다.

# %%
import os
# os.environ["JAVA_HOME"] = r"C:\Program Files\Java\jdk-21.0.11"

from konlpy.tag import Okt
from collections import Counter

# %%
document = '''
AI 에이전트는 사용자의 요구에 맞게 다양한 작업을 자동으로 수행하고 지원하는 인공지능 (AI) 시스템으로, 개인의 일정 관리,정보 검색과 제공, 통신 기능, 스마트홈 관리, 언어 번역과 대화 등의 다양한 기능을 수행한다. 예컨대 AI 에이전트는 스스로 마우스 커서를 움직여 텍스트를 입력하고, 이메일을 보내거나 쇼핑하는 등 사람을 대신해 복잡한 컴퓨터 작업을 수행한다. 이는 특정 목표를 달성하기 위해 스스로 계획을 수립하고 실행하는 추론과 행동이 가능하다는 점에서 단순한 AI 챗봇 수준을 넘어선 것이다.

AI 에이전트는 크게 3단계로 작동하는데, 우선 센서를 통해 환경의 상태를 감지하거나 데이터를 수집하는 것이 첫 번째이다. 이후 입력 데이터를 분석하고 이를 바탕으로 목표 달성을 위한 최적의 행동을 계획하는 생각(Think)을 거쳐, 계획된 행동(Act)을 실행하여 환경에 영향을 미치게 된다. 이처럼 사용자가 명령을 내리면 AI 에이전트는 자연어 처리 능력을 기반으로 맥락을 이해하고 정확하고 검증된 결과를 제공한다. 예컨대 자율주행차의 경우 환경 데이터를 분석해 최적의 경로를 선태하고 장애물과 충돌을 피하는 역할을 하며, 스마트홈에서는 사용자의 행동에 따라 에어컨·조명 등의 각종 가전제품을 자동으로 조절한다. 또 금융 분야에서는 금융사기 탐지와 각 개인에 맞는 투자를 추천하며, 의료 분야에서는 환자의 데이터를 분석해 질병 진단 및 치료계획을 지원하는 역할을 한다. 

이처럼 AI 에이전트는 반복적이고 시간이 많이 드는 작업을 효율적으로 처리할 수 있고, 환경 변화에 빠르게 대응할 수 있으며, 데이터를 분석해 사람보다 정확한 의사 결정을 내릴 수 있다는 장점이 있다. 반면 품질 높은 데이터가 없으면 성능이 저하되고, 편향된 학습의 위험이 있으며, 예측 불가능한 환경에서는 성능이 제한될 수 있다는 단점이 있다. 
'''

# %%
# 명사만 추출
okt = Okt()

morphs = okt.nouns(document)
morphs
# Out:
# ['에이전트',
#  '사용자',
#  '요구',
#  '작업',
#  '자동',
#  '수행',
#  '지원',
#  '인공',
#  '지능',
#  '시스템',
#  '개인',
#  '일정',
#  '관리',
#  '정보',
#  '검색',
#  '제공',
#  '통신',
#  '기능',
#  '스마트홈',
#  '관리',
#  '언어',
#  '번역',
#  '대화',
#  '등',
#  '기능',
#  '수행',
#  '에이전트',
#  '스스로',
#  '마우스',
#  '커서',
#  '텍스트',
#  '입력',
#  '이메일',
#  '쇼핑',
#  '등',
#  '사람',
#  '대신',
#  '컴퓨터',
#  '작업',
#  '수행',
#  '특정',
#  '목표',
#  '달성',
#  '위해',
#  '스스로',
#  '계획',
#  '수립',
#  '실행',
#  '추론',
#  '행동',
#  '점',
#  '챗봇',
#  '수준',
#  '것',
#  '에이전트',
#  '크게',
#  '단계',
#  '작동',
#  '우선',
#  '센서',
#  '통해',
#  '환경',
#  '상태',
#  '데이터',
#  '수집',
#  '것',
#  '첫',
#  '번',
#  '이후',
#  '입력',
#  '데이터',
#  '분석',
#  '바탕',
#  '목표',
#  '달성',
#  '위',
#  '최적',
#  '행동',
#  '계획',
#  '생각',
#  '계획',
#  '행동',
#  '실행',
#  '환경',
#  '영향',
#  '이처럼',
#  '사용자',
#  '명령',
#  '에이전트',
#  '자연어',
#  '처리',
#  '능력',
#  '기반',
#  '맥락',
#  '이해',
#  '검증',
#  '결과',
#  '제공',
#  '자율',
#  '행차',
#  '경우',
#  '환경',
#  '데이터',
#  '분석',
#  '최적',
#  '경로',
#  '선태',
#  '장애물',
#  '충돌',
#  '피하',
#  '역할',
#  '스마트홈',
#  '사용자',
#  '행동',
#  '에어컨',
#  '조명',
#  '등',
#  '각종',
#  '가전제품',
#  '자동',
#  '조절',
#  '또',
#  '금융',
#  '분야',
#  '금융',
#  '사기',
#  '탐지',
#  '각',
#  '개인',
#  '투자',
#  '추천',
#  '의료',
#  '분야',
#  '환자',
#  '데이터',
#  '분석',
#  '질병',
#  '진단',
#  '및',
#  '치료',
#  '계획',
#  '지원',
#  '역할',
#  '이처럼',
#  '에이전트',
#  '반복',
#  '시간',
#  '작업',
#  '효율',
#  '처리',
#  '수',
#  '환경',
#  '변화',
#  '대응',
#  '수',
#  '데이터',
#  '분석',
#  '사람',
#  '의사',
#  '결정',
#  '수',
#  '장점',
#  '반면',
#  '품질',
#  '데이터',
#  '성능',
#  '저하',
#  '편향',
#  '학습',
#  '위험',
#  '예측',
#  '환경',
#  '성능',
#  '제한',
#  '수',
#  '단점']

# %%
# 빈도수 분석
freq_dict = dict(Counter(morphs))
freq_dict

sorted_dict = sorted(freq_dict.items(),
                     key = lambda item : item[1],       # 튜플의 두 번째 요소(빈도수)를 정렬 기준으로 사용
                     reverse = True                     # 내림차순
                     )
sorted_dict
# Out:
# [('데이터', 6),
#  ('에이전트', 5),
#  ('환경', 5),
#  ('계획', 4),
#  ('행동', 4),
#  ('분석', 4),
#  ('수', 4),
#  ('사용자', 3),
#  ('작업', 3),
#  ('수행', 3),
#  ('등', 3),
#  ('자동', 2),
#  ('지원', 2),
#  ('개인', 2),
#  ('관리', 2),
#  ('제공', 2),
#  ('기능', 2),
#  ('스마트홈', 2),
#  ('스스로', 2),
#  ('입력', 2),
#  ('사람', 2),
#  ('목표', 2),
#  ('달성', 2),
#  ('실행', 2),
#  ('것', 2),
#  ('최적', 2),
#  ('이처럼', 2),
#  ('처리', 2),
#  ('역할', 2),
#  ('금융', 2),
#  ('분야', 2),
#  ('성능', 2),
#  ('요구', 1),
#  ('인공', 1),
#  ('지능', 1),
#  ('시스템', 1),
#  ('일정', 1),
#  ('정보', 1),
#  ('검색', 1),
#  ('통신', 1),
#  ('언어', 1),
#  ('번역', 1),
#  ('대화', 1),
#  ('마우스', 1),
#  ('커서', 1),
#  ('텍스트', 1),
#  ('이메일', 1),
#  ('쇼핑', 1),
#  ('대신', 1),
#  ('컴퓨터', 1),
#  ('특정', 1),
#  ('위해', 1),
#  ('수립', 1),
#  ('추론', 1),
#  ('점', 1),
#  ('챗봇', 1),
#  ('수준', 1),
#  ('크게', 1),
#  ('단계', 1),
#  ('작동', 1),
#  ('우선', 1),
#  ('센서', 1),
#  ('통해', 1),
#  ('상태', 1),
#  ('수집', 1),
#  ('첫', 1),
#  ('번', 1),
#  ('이후', 1),
#  ('바탕', 1),
#  ('위', 1),
#  ('생각', 1),
#  ('영향', 1),
#  ('명령', 1),
#  ('자연어', 1),
#  ('능력', 1),
#  ('기반', 1),
#  ('맥락', 1),
#  ('이해', 1),
#  ('검증', 1),
#  ('결과', 1),
#  ('자율', 1),
#  ('행차', 1),
#  ('경우', 1),
#  ('경로', 1),
#  ('선태', 1),
#  ('장애물', 1),
#  ('충돌', 1),
#  ('피하', 1),
#  ('에어컨', 1),
#  ('조명', 1),
#  ('각종', 1),
#  ('가전제품', 1),
#  ('조절', 1),
#  ('또', 1),
#  ('사기', 1),
#  ('탐지', 1),
#  ('각', 1),
#  ('투자', 1),
#  ('추천', 1),
#  ('의료', 1),
#  ('환자', 1),
#  ('질병', 1),
#  ('진단', 1),
#  ('및', 1),
#  ('치료', 1),
#  ('반복', 1),
#  ('시간', 1),
#  ('효율', 1),
#  ('변화', 1),
#  ('대응', 1),
#  ('의사', 1),
#  ('결정', 1),
#  ('장점', 1),
#  ('반면', 1),
#  ('품질', 1),
#  ('저하', 1),
#  ('편향', 1),
#  ('학습', 1),
#  ('위험', 1),
#  ('예측', 1),
#  ('제한', 1),
#  ('단점', 1)]

# %%
import pandas as pd

df = pd.DataFrame(sorted_dict)
df.index = df[0]
del df[0]
df
# Out:
#       1
# 0
# 데이터   6
# 에이전트  5
# 환경    5
# 계획    4
# 행동    4
# ...  ..
# 학습    1
# 위험    1
# 예측    1
# 제한    1
# 단점    1
#
# [122 rows x 1 columns]

# %% [markdown]
# # 2.워드클라우드

# %%
df = pd.read_csv('data/배달의민족댓글.csv')

df
# Out:
#      Unnamed: 0                                                 댓글
# 0             0                                                NaN
# 1             1                                                NaN
# 2             2                                                NaN
# 3             3  80분 걸린다길래 주문취소 하려고 주문내역에 들어가면 계속 최신 정보를 불러오지 못...
# 4             4  음식 하나 시키는데 우리나라 앱들은 1) 국내 번호 필요함. 번호 인증 필수 2) ...
# ..          ...                                                ...
# 458         458  우선 배달업체 광고가 너무 많습니다. 두번째는 주문직전 주소바꾸기 안되는게 매우매우...
# 459         459  배민 쭉 써왔고 쓴소리 하나 하려합니다. 중간다리 플랫폼으로서 식당/유저 사이 중재...
# 460         460  업데이트된거 디자인 너무 불편해요. 배민1 부분에서 음식점 둘러보는데 빨리 한거번에...
# 461         461  첫주문도 아닌데 첫주문 할인받으로 광고 계속오고 친구초대 하려하니까 주문내역이 없다...
# 462         462  메뉴 잘못와서 문의하는데 채팅 답변하는데만 20분 걸림 메뉴 다시받는데 1시간 걸림...
#
# [463 rows x 2 columns]

# %%
# 인덱스와 댓글만 나오도록
df = df.dropna()
df = df.reset_index()
df.drop(['index','Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#                                                   댓글
# 0  80분 걸린다길래 주문취소 하려고 주문내역에 들어가면 계속 최신 정보를 불러오지 못...
# 1  음식 하나 시키는데 우리나라 앱들은 1) 국내 번호 필요함. 번호 인증 필수 2) ...
# 2  왜이렇게 업데이트 할때마다 사용하기 점점 불편하게 바뀌는지? 클릭한번 더 해야되고 ...
# 3  배달의 민족앱자체는 만족하나, 식사후 맛 리뷰 평점 자체는 클린하게 이뤄지진 못하는...
# 4  장바구니가 너무 불편합니다. 비마트에서 여러가지를 담고 스크롤 올리고 내릴때 살짝 ...

# %%
df = df.drop_duplicates(subset=['댓글'])        # '댓글' 열을 기준으로 중복된 행을 제거
df
# Out:
#                                                     댓글
# 0    80분 걸린다길래 주문취소 하려고 주문내역에 들어가면 계속 최신 정보를 불러오지 못...
# 1    음식 하나 시키는데 우리나라 앱들은 1) 국내 번호 필요함. 번호 인증 필수 2) ...
# 2    왜이렇게 업데이트 할때마다 사용하기 점점 불편하게 바뀌는지? 클릭한번 더 해야되고 ...
# 3    배달의 민족앱자체는 만족하나, 식사후 맛 리뷰 평점 자체는 클린하게 이뤄지진 못하는...
# 4    장바구니가 너무 불편합니다. 비마트에서 여러가지를 담고 스크롤 올리고 내릴때 살짝 ...
# ..                                                 ...
# 455  우선 배달업체 광고가 너무 많습니다. 두번째는 주문직전 주소바꾸기 안되는게 매우매우...
# 456  배민 쭉 써왔고 쓴소리 하나 하려합니다. 중간다리 플랫폼으로서 식당/유저 사이 중재...
# 457  업데이트된거 디자인 너무 불편해요. 배민1 부분에서 음식점 둘러보는데 빨리 한거번에...
# 458  첫주문도 아닌데 첫주문 할인받으로 광고 계속오고 친구초대 하려하니까 주문내역이 없다...
# 459  메뉴 잘못와서 문의하는데 채팅 답변하는데만 20분 걸림 메뉴 다시받는데 1시간 걸림...
#
# [460 rows x 1 columns]

# %%
text_data = ''

for temp in df['댓글']:
    text_data = text_data + ' ' + temp

text_data
# Out:
# ' 80분 걸린다길래 주문취소 하려고 주문내역에 들어가면 계속 최신 정보를 불러오지 못했다고만 로딩반복. 로딩 이미지는 깨져서 나오고 안정적인 네트워크 상황 하에서 새로고침을 눌러도 무한로딩이고 심지어 지금 진행중인 주문내역 정보조차 정확하지 않음. 코로나 때문에 서버가 불안정한건지 뭔지는 모르겠으나 결국엔 취소 못하고 꼼짝없이 기다려 먹게됐네요. 음식 하나 시키는데 우리나라 앱들은 1) 국내 번호 필요함. 번호 인증 필수 2) 카드 결제선택시 또 다른 은행앱을 깔고 인증을 한 3번정도 더 해야함... 해외카드로 결제수단은 아예없고 왜 현금결제 옵션도 없나요... 음식하나 시켜먹는데 이렇게 복잡한 나라 우리나라 밖에없습니다 IT강국은 무슨... 왜 핸드폰 번호 인증, 카드인증등 불편하게 스탭이 많나요 앱 사용중에도 UI/UX, front-end 쪽으로도 다 너무 짜증나고 결국 저녁도 못시켜먹음 하... 외국거주자는 방법이 없네요 왜 해외카드는 결제가 안되나요.... 왜이렇게 업데이트 할때마다 사용하기 점점 불편하게 바뀌는지? 클릭한번 더 해야되고 더 번거롭게 바뀌네요. 일반결제가 기본임에도 저쪽 구석으로 밀려나고 마치 한집배달을 유도하듯 메인에 만들어 놔서 잘못 클릭하면 자꾸 나가서 일반결제를 다시 클릭해야하게 만들어놓더니. 이젠 결제창에 요청사항이나 리뷰이벤트할때 또 클릭해서 하게끔 바뀌었네요. 쓸데없는 짓 정말 잘하네요 배민. 배달의 민족앱자체는 만족하나, 식사후 맛 리뷰 평점 자체는 클린하게 이뤄지진 못하는것 같습니다.. 식당입장, 그러니까 업주 입장에서는 높은 별점으로 인한 주문건수를 기대하려 하겠지만, 주문자 입장에서는 맛이 없는 식당들도 대체적으로 4.8점이 넘어 정확한 맛집 탐색이 어렵다는 점에서 앱자체에 대한 평점은 3점으로 남겨 놓습니다.. 즐거운 식사를 항상 추구하고 기대하나 평점에 속아 그러지 못해 이를 애석하게 생각하고 있습니다! 수고하시는 어플리케이션 개발자 여러분들 좋은 아이디어로 참신한 방법을 구안해 내시길 바라며 이만 줄입니다.! 장바구니가 너무 불편합니다. 비마트에서 여러가지를 담고 스크롤 올리고 내릴때 살짝 대각선으로 움직이면 배달포장 대용량특가등 좌우로 넘어가 버리고 비마트 항목으로 다시 넘어오면 체크해둔 상태가 아닌 리로딩 되어 맨위로 올라가고 전체선택이 됩니다. 너무 예민해서 살짝만 직선에서 벗어나도 옆 항목으로 가는데 쓸때마다 짜증나더라고요. 위에 배달포장 비마트 대용량특가...등 항목을 눌러서 선택해도 될듯한데 화면을 옆으로 넘길 필요까진 없는듯합니다. 거의 매일 배민 어플 사용하면서 느낀점입니다. B마트 이용중인데 언제부턴가 전체선택 버튼이 비활성화되어있습니다. 장바구니에 있는것 중에 원하는걸 구매하려면 체크박스를 해제하면서 스크롤을 내려야하고 화면을 꾹 눌렀다 떼거나 터치를 잘못하면 페이지가 새로고침되고 선택한게 초기화됩니다. 결제 넘어가기전에 선택제품이 뭔지 한번 더 볼 수 있으면 좋겠어요. 수저포크x 버튼 기본으로 활성화 되어있는거 환경 보호한다고 해놓은거 압니다. 그런데 그거랑 별개로 사용자가 기본설정을 바꿀 수 있게 해줘야지 결제창 껏다가 다시 열면 또 체크되어있어서 조금만 까먹으면 수저없이 밥먹기 일수입니다. 기능을 삭제하는게 아니라 디폴트 설정을 바꿀 수 있게 옵션에 추가해주세요. 저는 직장에서 점심 먹을때 맨손으로 먹기 싫습니다. 이렇게 주문 실수때 젓가락 안받아봤자 결국 먹을 방법이 없어 편의점에서 하나 가져오게 만들 뿐 환경에는 도움이 안됩니다. 개선이되고 업데이트가 된다는건 불편했던 사항들을 반영하는것 아닌가요? 오히려 더 불편해서 보기가 싫을정도입니다 너무 불편하고 더 조잡스러워 보여요 ; 안보이는 식당은 일일히 검색해서 찾아야하고 찾아야 나오고 그전 버전이 훨씬 편합니다ㅡㅡ 사용자만 볼 수있는 배달시켰던 가게들에 대한 메모기능?이랑 언제 몇번 먹었다 같은걸 볼수있는 기능같은게 있었으면 좋겠어요. 여러가게에서 배달을 자주 시켜먹는데 조금 시간이 지나면 그가게 음식의 맛이나 재주문할만한 집이었는지 아니었는지 내가 여기서 시켜먹어본 집이었는지 아닌지 기억이 잘 안나요. 저는 알뜰이나 한집배달이용을 원치않는데 가게검색시에는 가게배달은 선택할수가없네요. 뭔가 언제부턴가 어플이용이 많이 불편해졌습니다. 배민을 제일 많이이용했는데 고객선택이아닌 알뜰이나 한집배달을 유도하는거같아 사용하기 꺼려집니다. 알뜰은 싸지만 음식이 다식어서오고 한집은 배달비면에서 부담인데 참 불편합니다. 실시간 채팅상담 해결해주지도 못하는데 없는게 나을 것 같음. 결제수단 변경 요청했더니 이미 출발해서 변경이 어렵다고하네요. 본인들 답변 확인이 늦어서 늦게 확인해서 가게에서 이미 출발함. 나몰라라 문의량 많아서 답변이 느려 미안하다는 말만 반복함.... 그리고 이미 출발했어도 재주문하고 라이더는 안잡히게 해서 재처리해줄수있는 기능도 없나봄. 또는 귀찮아서 처리 안해줬나 그럴거면 직접 빠르게 해결할수 있게 가게 번호라도 적어놓던가 별점 하나도 아까움 ㅎ 배차 관리도 못하고 업주한테든 고객한테든 제대로 된 보상도 없고 채팅으로도 전화로도 상담원 연결 안 될거면 왜 만든건지 ? 등급도 의미 없어진지 오래지만 처음부터 써왔기에 불편한 거 감수하고 계속 사용했는데 도저히 못해먹겠네 망하라고 저주 안 해도 이미 망해가는 듯 찜 기능에 폴더로 분류할 수 있는 기능이 있었으면 좋겠습니다. 배달팁이 저렴한 가게, 맛있던 가게, 식사목적, 후식목적 이런 가게들을 다 찜 해놓고 사용하고 있었는데 수가 많아지다보니 구분하는 게 어려워요 왜 배달이 사라지고 자체배달이 생긴걸까요? 이제 알뜰이랑 한집배달만 남은건가요? 일반 배달은 없는건가요? 홈화면을 직접 설정할 수 있는 기능이 있으면 좋을 것 같네요. 그리고 예를들어 치킨을 검색한 후 찜 많은 순으로 하면 중간에 찜갯수가 낮은 가게들은 뭔가요? 찜 많은 순이 찜 많은 순이 아니게 되었어요 광고비를 받아서 한다고 해도 너무 심합니다,,,, 편의점 꺼 30분을 기다렸는데 갑자기 기타 사유로 주문이 취소가 됐어요. 평소에 워낙 친절한 매장이라 이게 무슨 일이지 하고 전화를 걸어보려 했는데 그 매장이 아니라 편의점 고객센터로 연결되네요? 심지어 주말이라 고객센터는 받지도 않고..ㅠㅠㅠ 계속 기다렸는데.. 곧 나가야 해서 이제 와서 다른 걸 시킬 수도 없고요 바쁠 수도 있고 재고가 없을 수도 있는 거 다 이해하고 평소에 친절하게 대응했던 매장이라 엄청 화는 안 나요 다만 오래 기다렸으니까 취소할 때는 왜 안되는지 정확한 사유를 말해주셨으면 좋겠어요 그리고 편의점에서 부족한 게 있을 때 부분 취소는 안되는 걸까요? 안된다면 이런 점도 개선됐으면 좋겠어요 그래야 서로 편할거같아요 저도 배민 이용하면서 늘 생각했던게, 가게를 차단할 수 있는 기능같은게 생기면 좋겠어요. 단골 식당이 휴일일때 다신 안시켜먹고 싶은 식당에서 주문해버린 적이 있었어요. 기억해 뒀다가 피해야지 했다가도 한참 시간이 지나니까 깜박하고 실수로 주문하게 되더라구요..;; 자주 시키는 것도 아니니까 ㅠㅠ 식당 차단 기능이나 찜 반대 기능 같은 것 좀 넣어주세요 다른건 다 괜찮은데 위아래로 스크롤 하는데. 계속 잘못 인식하고 옆으로 갑니다. 예를들어 B마트에서 물건 고르려고 위래로 움직이는데 계속 포장 쪽으로 이동합니다. 매우 센시티브합니다. 앱개선이 필요해 보입니다. 너무 불편해요 개짜증나요 진짜 개열받게 디폴트를 수저 포크o으로 바꾸시라고요. 결제방법 변경이나 오류로 다시 결제만 했다하면 수저 포크x 되어있어서 아주 짜증나네요. 맨날 체크하다가도 결제창 내에서 다시 시도한건데도 이러는 거 진짜 짜증나요 너무 짜증나서 후기 남깁니다 배민은 좀 바꾸세요 한집배달로 20~30분 뒤에 집에 도착한다고 되어있어서 주문했더니 40분이 지나도 도착은 커녕 배차도 안 됨. 이런 식으로 속은 게 한두번이 아님. 예상시간을 똑바로 적어놓거나 한집배달 시스템 자체를 갈아엎어야 할 듯. 그리고 주문 후에도 도착 예정시간이 점점 늘어남. 기존 VIP 혜택이 그렇게 큰것도 아니였는데 왜 브랜드쿠폰이랑 묶어서 사용할수있게 바뀐건지 이해할수가없네요. 그것도 아무런 공지도없이 갑작스럽게. 브랜드 자체쿠폰에 겨우 천원 더 할인되는게 누가 좋아한다 ...

# %%
# %pip install wordcloud
# uv add wordcloud

# %%
# 워드클라우드 라이브러리 불러오기
from wordcloud import WordCloud
import re

# %%
# 한글, 공백을 제외한 모든 문자 제거

kor_data = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣\s]', '', text_data)
kor_data
# Out:
# ' 분 걸린다길래 주문취소 하려고 주문내역에 들어가면 계속 최신 정보를 불러오지 못했다고만 로딩반복 로딩 이미지는 깨져서 나오고 안정적인 네트워크 상황 하에서 새로고침을 눌러도 무한로딩이고 심지어 지금 진행중인 주문내역 정보조차 정확하지 않음 코로나 때문에 서버가 불안정한건지 뭔지는 모르겠으나 결국엔 취소 못하고 꼼짝없이 기다려 먹게됐네요 음식 하나 시키는데 우리나라 앱들은  국내 번호 필요함 번호 인증 필수  카드 결제선택시 또 다른 은행앱을 깔고 인증을 한 번정도 더 해야함 해외카드로 결제수단은 아예없고 왜 현금결제 옵션도 없나요 음식하나 시켜먹는데 이렇게 복잡한 나라 우리나라 밖에없습니다 강국은 무슨 왜 핸드폰 번호 인증 카드인증등 불편하게 스탭이 많나요 앱 사용중에도   쪽으로도 다 너무 짜증나고 결국 저녁도 못시켜먹음 하 외국거주자는 방법이 없네요 왜 해외카드는 결제가 안되나요 왜이렇게 업데이트 할때마다 사용하기 점점 불편하게 바뀌는지 클릭한번 더 해야되고 더 번거롭게 바뀌네요 일반결제가 기본임에도 저쪽 구석으로 밀려나고 마치 한집배달을 유도하듯 메인에 만들어 놔서 잘못 클릭하면 자꾸 나가서 일반결제를 다시 클릭해야하게 만들어놓더니 이젠 결제창에 요청사항이나 리뷰이벤트할때 또 클릭해서 하게끔 바뀌었네요 쓸데없는 짓 정말 잘하네요 배민 배달의 민족앱자체는 만족하나 식사후 맛 리뷰 평점 자체는 클린하게 이뤄지진 못하는것 같습니다 식당입장 그러니까 업주 입장에서는 높은 별점으로 인한 주문건수를 기대하려 하겠지만 주문자 입장에서는 맛이 없는 식당들도 대체적으로 점이 넘어 정확한 맛집 탐색이 어렵다는 점에서 앱자체에 대한 평점은 점으로 남겨 놓습니다 즐거운 식사를 항상 추구하고 기대하나 평점에 속아 그러지 못해 이를 애석하게 생각하고 있습니다 수고하시는 어플리케이션 개발자 여러분들 좋은 아이디어로 참신한 방법을 구안해 내시길 바라며 이만 줄입니다 장바구니가 너무 불편합니다 비마트에서 여러가지를 담고 스크롤 올리고 내릴때 살짝 대각선으로 움직이면 배달포장 대용량특가등 좌우로 넘어가 버리고 비마트 항목으로 다시 넘어오면 체크해둔 상태가 아닌 리로딩 되어 맨위로 올라가고 전체선택이 됩니다 너무 예민해서 살짝만 직선에서 벗어나도 옆 항목으로 가는데 쓸때마다 짜증나더라고요 위에 배달포장 비마트 대용량특가등 항목을 눌러서 선택해도 될듯한데 화면을 옆으로 넘길 필요까진 없는듯합니다 거의 매일 배민 어플 사용하면서 느낀점입니다 마트 이용중인데 언제부턴가 전체선택 버튼이 비활성화되어있습니다 장바구니에 있는것 중에 원하는걸 구매하려면 체크박스를 해제하면서 스크롤을 내려야하고 화면을 꾹 눌렀다 떼거나 터치를 잘못하면 페이지가 새로고침되고 선택한게 초기화됩니다 결제 넘어가기전에 선택제품이 뭔지 한번 더 볼 수 있으면 좋겠어요 수저포크 버튼 기본으로 활성화 되어있는거 환경 보호한다고 해놓은거 압니다 그런데 그거랑 별개로 사용자가 기본설정을 바꿀 수 있게 해줘야지 결제창 껏다가 다시 열면 또 체크되어있어서 조금만 까먹으면 수저없이 밥먹기 일수입니다 기능을 삭제하는게 아니라 디폴트 설정을 바꿀 수 있게 옵션에 추가해주세요 저는 직장에서 점심 먹을때 맨손으로 먹기 싫습니다 이렇게 주문 실수때 젓가락 안받아봤자 결국 먹을 방법이 없어 편의점에서 하나 가져오게 만들 뿐 환경에는 도움이 안됩니다 개선이되고 업데이트가 된다는건 불편했던 사항들을 반영하는것 아닌가요 오히려 더 불편해서 보기가 싫을정도입니다 너무 불편하고 더 조잡스러워 보여요  안보이는 식당은 일일히 검색해서 찾아야하고 찾아야 나오고 그전 버전이 훨씬 편합니다ㅡㅡ 사용자만 볼 수있는 배달시켰던 가게들에 대한 메모기능이랑 언제 몇번 먹었다 같은걸 볼수있는 기능같은게 있었으면 좋겠어요 여러가게에서 배달을 자주 시켜먹는데 조금 시간이 지나면 그가게 음식의 맛이나 재주문할만한 집이었는지 아니었는지 내가 여기서 시켜먹어본 집이었는지 아닌지 기억이 잘 안나요 저는 알뜰이나 한집배달이용을 원치않는데 가게검색시에는 가게배달은 선택할수가없네요 뭔가 언제부턴가 어플이용이 많이 불편해졌습니다 배민을 제일 많이이용했는데 고객선택이아닌 알뜰이나 한집배달을 유도하는거같아 사용하기 꺼려집니다 알뜰은 싸지만 음식이 다식어서오고 한집은 배달비면에서 부담인데 참 불편합니다 실시간 채팅상담 해결해주지도 못하는데 없는게 나을 것 같음 결제수단 변경 요청했더니 이미 출발해서 변경이 어렵다고하네요 본인들 답변 확인이 늦어서 늦게 확인해서 가게에서 이미 출발함 나몰라라 문의량 많아서 답변이 느려 미안하다는 말만 반복함 그리고 이미 출발했어도 재주문하고 라이더는 안잡히게 해서 재처리해줄수있는 기능도 없나봄 또는 귀찮아서 처리 안해줬나 그럴거면 직접 빠르게 해결할수 있게 가게 번호라도 적어놓던가 별점 하나도 아까움 ㅎ 배차 관리도 못하고 업주한테든 고객한테든 제대로 된 보상도 없고 채팅으로도 전화로도 상담원 연결 안 될거면 왜 만든건지  등급도 의미 없어진지 오래지만 처음부터 써왔기에 불편한 거 감수하고 계속 사용했는데 도저히 못해먹겠네 망하라고 저주 안 해도 이미 망해가는 듯 찜 기능에 폴더로 분류할 수 있는 기능이 있었으면 좋겠습니다 배달팁이 저렴한 가게 맛있던 가게 식사목적 후식목적 이런 가게들을 다 찜 해놓고 사용하고 있었는데 수가 많아지다보니 구분하는 게 어려워요 왜 배달이 사라지고 자체배달이 생긴걸까요 이제 알뜰이랑 한집배달만 남은건가요 일반 배달은 없는건가요 홈화면을 직접 설정할 수 있는 기능이 있으면 좋을 것 같네요 그리고 예를들어 치킨을 검색한 후 찜 많은 순으로 하면 중간에 찜갯수가 낮은 가게들은 뭔가요 찜 많은 순이 찜 많은 순이 아니게 되었어요 광고비를 받아서 한다고 해도 너무 심합니다 편의점 꺼 분을 기다렸는데 갑자기 기타 사유로 주문이 취소가 됐어요 평소에 워낙 친절한 매장이라 이게 무슨 일이지 하고 전화를 걸어보려 했는데 그 매장이 아니라 편의점 고객센터로 연결되네요 심지어 주말이라 고객센터는 받지도 않고ㅠㅠㅠ 계속 기다렸는데 곧 나가야 해서 이제 와서 다른 걸 시킬 수도 없고요 바쁠 수도 있고 재고가 없을 수도 있는 거 다 이해하고 평소에 친절하게 대응했던 매장이라 엄청 화는 안 나요 다만 오래 기다렸으니까 취소할 때는 왜 안되는지 정확한 사유를 말해주셨으면 좋겠어요 그리고 편의점에서 부족한 게 있을 때 부분 취소는 안되는 걸까요 안된다면 이런 점도 개선됐으면 좋겠어요 그래야 서로 편할거같아요 저도 배민 이용하면서 늘 생각했던게 가게를 차단할 수 있는 기능같은게 생기면 좋겠어요 단골 식당이 휴일일때 다신 안시켜먹고 싶은 식당에서 주문해버린 적이 있었어요 기억해 뒀다가 피해야지 했다가도 한참 시간이 지나니까 깜박하고 실수로 주문하게 되더라구요 자주 시키는 것도 아니니까 ㅠㅠ 식당 차단 기능이나 찜 반대 기능 같은 것 좀 넣어주세요 다른건 다 괜찮은데 위아래로 스크롤 하는데 계속 잘못 인식하고 옆으로 갑니다 예를들어 마트에서 물건 고르려고 위래로 움직이는데 계속 포장 쪽으로 이동합니다 매우 센시티브합니다 앱개선이 필요해 보입니다 너무 불편해요 개짜증나요 진짜 개열받게 디폴트를 수저 포크으로 바꾸시라고요 결제방법 변경이나 오류로 다시 결제만 했다하면 수저 포크 되어있어서 아주 짜증나네요 맨날 체크하다가도 결제창 내에서 다시 시도한건데도 이러는 거 진짜 짜증나요 너무 짜증나서 후기 남깁니다 배민은 좀 바꾸세요 한집배달로 분 뒤에 집에 도착한다고 되어있어서 주문했더니 분이 지나도 도착은 커녕 배차도 안 됨 이런 식으로 속은 게 한두번이 아님 예상시간을 똑바로 적어놓거나 한집배달 시스템 자체를 갈아엎어야 할 듯 그리고 주문 후에도 도착 예정시간이 점점 늘어남 기존  혜택이 그렇게 큰것도 아니였는데 왜 브랜드쿠폰이랑 묶어서 사용할수있게 바뀐건지 이해할수가없네요 그것도 아무런 공지도없이 갑작스럽게 브랜드 자체쿠폰에 겨우 천원 더 할인되는게 누가 좋아한다고 그렇게 하는지 모르겠네요  혜택 생기고 한번도 놓친적 없을정도로 정말 배민 사용 많이 했었는데 사용하고싶은마음이 싹 사라지네요 원래도 최소주문금액이상 주문해야 사용할수있었는데 지금은 최소주문금액에 브랜드도 일주일에 개 딱 정해져있고 먹고싶은걸 시키는게아니라 혜택받고싶으면 쿠 ...

# %%
# 한글 정제된 데이터에 대해 품사 태깅

okt = Okt()
okt_data = okt.pos(kor_data)
okt_data

# 반환 결과 : 리스트형식 (단어, 품사 태그) 형태의 튜플로 구성
# Out:
# [('분', 'Noun'),
#  ('걸린다길래', 'Verb'),
#  ('주문', 'Noun'),
#  ('취소', 'Noun'),
#  ('하려고', 'Verb'),
#  ('주', 'Modifier'),
#  ('문', 'Modifier'),
#  ('내', 'Modifier'),
#  ('역', 'Noun'),
#  ('에', 'Josa'),
#  ('들어가면', 'Verb'),
#  ('계속', 'Noun'),
#  ('최신', 'Noun'),
#  ('정보', 'Noun'),
#  ('를', 'Josa'),
#  ('불러오지', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('했다고만', 'Verb'),
#  ('로딩', 'Noun'),
#  ('반복', 'Noun'),
#  ('로딩', 'Noun'),
#  ('이미지', 'Noun'),
#  ('는', 'Josa'),
#  ('깨져서', 'Verb'),
#  ('나오고', 'Verb'),
#  ('안정', 'Noun'),
#  ('적', 'Suffix'),
#  ('인', 'Josa'),
#  ('네트워크', 'Noun'),
#  ('상황', 'Noun'),
#  ('하', 'Noun'),
#  ('에서', 'Josa'),
#  ('새로고침', 'Noun'),
#  ('을', 'Josa'),
#  ('눌러도', 'Verb'),
#  ('무한', 'Noun'),
#  ('로딩', 'Noun'),
#  ('이고', 'Josa'),
#  ('심지어', 'Noun'),
#  ('지금', 'Noun'),
#  ('진행중', 'Noun'),
#  ('인', 'Josa'),
#  ('주', 'Modifier'),
#  ('문', 'Modifier'),
#  ('내', 'Modifier'),
#  ('역', 'Noun'),
#  ('정보', 'Noun'),
#  ('조차', 'Josa'),
#  ('정확하지', 'Adjective'),
#  ('않음', 'Verb'),
#  ('코로나', 'Noun'),
#  ('때문', 'Noun'),
#  ('에', 'Josa'),
#  ('서버', 'Noun'),
#  ('가', 'Josa'),
#  ('불안정한', 'Adjective'),
#  ('건지', 'Verb'),
#  ('뭔', 'Noun'),
#  ('지는', 'Josa'),
#  ('모르겠으나', 'Verb'),
#  ('결국', 'Adverb'),
#  ('엔', 'Josa'),
#  ('취소', 'Noun'),
#  ('못', 'Noun'),
#  ('하고', 'Josa'),
#  ('꼼짝', 'Noun'),
#  ('없이', 'Adverb'),
#  ('기다려', 'Verb'),
#  ('먹게', 'Verb'),
#  ('됐네요', 'Verb'),
#  ('음식', 'Noun'),
#  ('하나', 'Noun'),
#  ('시키는데', 'Verb'),
#  ('우리나라', 'Noun'),
#  ('앱', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('국내', 'Noun'),
#  ('번호', 'Noun'),
#  ('필요함', 'Adjective'),
#  ('번호', 'Noun'),
#  ('인증', 'Noun'),
#  ('필수', 'Noun'),
#  ('카드', 'Noun'),
#  ('결제', 'Noun'),
#  ('선택', 'Noun'),
#  ('시', 'Noun'),
#  ('또', 'Noun'),
#  ('다른', 'Noun'),
#  ('은행', 'Noun'),
#  ('앱', 'Noun'),
#  ('을', 'Josa'),
#  ('깔고', 'Verb'),
#  ('인증', 'Noun'),
#  ('을', 'Josa'),
#  ('한', 'Verb'),
#  ('번', 'Noun'),
#  ('정도', 'Noun'),
#  ('더', 'Noun'),
#  ('해야', 'Verb'),
#  ('함', 'Noun'),
#  ('해외', 'Noun'),
#  ('카드', 'Noun'),
#  ('로', 'Josa'),
#  ('결제', 'Noun'),
#  ('수단', 'Noun'),
#  ('은', 'Josa'),
#  ('아예', 'Noun'),
#  ('없고', 'Adjective'),
#  ('왜', 'Noun'),
#  ('현금', 'Noun'),
#  ('결제', 'Noun'),
#  ('옵션', 'Noun'),
#  ('도', 'Josa'),
#  ('없나요', 'Adjective'),
#  ('음식', 'Noun'),
#  ('하나', 'Noun'),
#  ('시켜', 'Verb'),
#  ('먹는데', 'Verb'),
#  ('이렇게', 'Adverb'),
#  ('복잡한', 'Adjective'),
#  ('나라', 'Noun'),
#  ('우리나라', 'Noun'),
#  ('밖', 'Noun'),
#  ('에', 'Josa'),
#  ('없습니다', 'Adjective'),
#  ('강국', 'Noun'),
#  ('은', 'Josa'),
#  ('무슨', 'Noun'),
#  ('왜', 'Noun'),
#  ('핸드폰', 'Noun'),
#  ('번호', 'Noun'),
#  ('인증', 'Noun'),
#  ('카드', 'Noun'),
#  ('인증', 'Noun'),
#  ('등', 'Noun'),
#  ('불편하게', 'Adjective'),
#  ('스탭', 'Noun'),
#  ('이', 'Josa'),
#  ('많나요', 'Adjective'),
#  ('앱', 'Noun'),
#  ('사용', 'Noun'),
#  ('중', 'Suffix'),
#  ('에도', 'Josa'),
#  ('쪽', 'Noun'),
#  ('으로도', 'Josa'),
#  ('다', 'Adverb'),
#  ('너무', 'Adverb'),
#  ('짜증나고', 'Adjective'),
#  ('결국', 'Adverb'),
#  ('저녁', 'Noun'),
#  ('도', 'Josa'),
#  ('못', 'VerbPrefix'),
#  ('시켜', 'Verb'),
#  ('먹음', 'Noun'),
#  ('하', 'Exclamation'),
#  ('외국', 'Noun'),
#  ('거주', 'Noun'),
#  ('자', 'Suffix'),
#  ('는', 'Josa'),
#  ('방법', 'Noun'),
#  ('이', 'Josa'),
#  ('없네요', 'Adjective'),
#  ('왜', 'Noun'),
#  ('해외', 'Noun'),
#  ('카드', 'Noun'),
#  ('는', 'Josa'),
#  ('결제', 'Noun'),
#  ('가', 'Josa'),
#  ('안되나요', 'Adjective'),
#  ('왜', 'Noun'),
#  ('이렇게', 'Adverb'),
#  ('업데이트', 'Noun'),
#  ('할', 'Verb'),
#  ('때', 'Noun'),
#  ('마다', 'Josa'),
#  ('사용', 'Noun'),
#  ('하기', 'Verb'),
#  ('점점', 'Noun'),
#  ('불편하게', 'Adjective'),
#  ('바뀌는지', 'Verb'),
#  ('클릭', 'Noun'),
#  ('한번', 'Noun'),
#  ('더', 'Noun'),
#  ('해야되', 'Verb'),
#  ('고', 'Noun'),
#  ('더', 'Noun'),
#  ('번거롭게', 'Adjective'),
#  ('바뀌네요', 'Verb'),
#  ('일', 'Modifier'),
#  ('반', 'Modifier'),
#  ('결제', 'Noun'),
#  ('가', 'Josa'),
#  ('기', 'Modifier'),
#  ('본', 'Modifier'),
#  ('임', 'Noun'),
#  ('에도', 'Josa'),
#  ('저쪽', 'Noun'),
#  ('구석', 'Noun'),
#  ('으로', 'Josa'),
#  ('밀려나고', 'Verb'),
#  ('마치', 'Noun'),
#  ('한', 'Determiner'),
#  ('집', 'Noun'),
#  ('배달', 'Noun'),
#  ('을', 'Josa'),
#  ('유도', 'Noun'),
#  ('하', 'Suffix'),
#  ('듯', 'Noun'),
#  ('메인', 'Noun'),
#  ('에', 'Josa'),
#  ('만들어', 'Verb'),
#  ('놔서', 'Verb'),
#  ('잘못', 'Noun'),
#  ('클릭', 'Noun'),
#  ('하면', 'Verb'),
#  ('자꾸', 'Noun'),
#  ('나가서', 'Verb'),
#  ('일', 'Modifier'),
#  ('반', 'Modifier'),
#  ('결제', 'Noun'),
#  ('를', 'Josa'),
#  ('다시', 'Noun'),
#  ('클릭', 'Noun'),
#  ('해야하게', 'Verb'),
#  ('만들어놓더니', 'Verb'),
#  ('이', 'Determiner'),
#  ('젠', 'Noun'),
#  ('결제', 'Noun'),
#  ('창', 'Noun'),
#  ('에', 'Josa'),
#  ('요청', 'Noun'),
#  ('사항', 'Noun'),
#  ('이나', 'Josa'),
#  ('리뷰', 'Noun'),
#  ('이벤트', 'Noun'),
#  ('할', 'Verb'),
#  ('때', 'Noun'),
#  ('또', 'Noun'),
#  ('클릭', 'Noun'),
#  ('해서', 'Verb'),
#  ('하게', 'Verb'),
#  ('끔', 'Verb'),
#  ('바뀌었네요', 'Verb'),
#  ('쓸데없는', 'Adjective'),
#  ('짓', 'Noun'),
#  ('정말', 'Noun'),
#  ('잘', 'VerbPrefix'),
#  ('하네요', 'Verb'),
#  ('배민', 'Noun'),
#  ('배달', 'Noun'),
#  ('의', 'Josa'),
#  ('민족', 'Noun'),
#  ('앱', 'Noun'),
#  ('자체', 'Noun'),
#  ('는', 'Josa'),
#  ('만족하나', 'Adjective'),
#  ('식사', 'Noun'),
#  ('후', 'Noun'),
#  ('맛', 'Noun'),
#  ('리뷰', 'Noun'),
#  ('평점', 'Noun'),
#  ('자체', 'Noun'),
#  ('는', 'Josa'),
#  ('클린', 'Noun'),
#  ('하게', 'Verb'),
#  ('이뤄지진', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('하는것', 'Verb'),
#  ('같습니다', 'Adjective'),
#  ('식당', 'Noun'),
#  ('입장', 'Noun'),
#  ('그러니까', 'Adverb'),
#  ('업주', 'Noun'),
#  ('입장', 'Noun'),
#  ('에서는', 'Josa'),
#  ('높은', 'Adjective'),
#  ('별', 'Modifier'),
#  ('점', 'Noun'),
#  ('으로', 'Josa'),
#  ('인한', 'Adjective'),
#  ('주', 'Modifier'),
#  ('문건', 'Noun'),
#  ('수', 'Noun'),
#  ('를', 'Josa'),
#  ('기대하려', 'Adjective'),
#  ('하겠지만', 'Verb'),
#  ('주문', 'Noun'),
#  ('자', 'Suffix'),
#  ('입장', 'Noun'),
#  ('에서는', 'Josa'),
#  ('맛', 'Noun'),
#  ('이', 'Josa'),
#  ('없는', 'Adjective'),
#  ('식당', 'Noun'),
#  ('들', 'Suffix'),
#  ('도', 'Josa'),
#  ('대', 'Modifier'),
#  ('체적', 'Noun'),
#  ('으로', 'Josa'),
#  ('점', 'Noun'),
#  ('이', 'Josa'),
#  ('넘어', 'Verb'),
#  ('정확한', 'Adjective'),
#  ('맛집', 'Noun'),
#  ('탐색', 'Noun'),
#  ('이', 'Josa'),
#  ('어렵다는', 'Adjective'),
#  ('점', 'Noun'),
#  ('에서', 'Josa'),
#  ('앱', 'Noun'),
#  ('자체', 'Noun'),
#  ('에', 'Josa'),
#  ('대한', 'Noun'),
#  ('평점', 'Noun'),
#  ('은', 'Josa'),
#  ('점', 'Noun'),
#  ('으로', 'Josa'),
#  ('남겨', 'Verb'),
#  ('놓습니다', 'Verb'),
#  ('즐거운', 'Adjective'),
#  ('식사', 'Noun'),
#  ('를', 'Josa'),
#  ('항상', 'Noun'),
#  ('추구', 'Noun'),
#  ('하고', 'Josa'),
#  ('기대하나', 'Adjective'),
#  ('평점', 'Noun'),
#  ('에', 'Josa'),
#  ('속', 'Noun'),
#  ('아', 'Josa'),
#  ('그러지', 'Adjective'),
#  ('못', 'VerbPrefix'),
#  ('해', 'Verb'),
#  ('이를', 'Verb'),
#  ('애석하게', 'Adjective'),
#  ('생각', 'Noun'),
#  ('하고', 'Josa'),
#  ('있습니다', 'Adjective'),
#  ('수고', 'Noun'),
#  ('하시는', 'Verb'),
#  ('어플리케이션', 'Noun'),
#  ('개발자', 'Noun'),
#  ('여러분', 'Noun'),
#  ('들', 'Suffix'),
#  ('좋은', 'Adjective'),
#  ('아이디어', 'Noun'),
#  ('로', 'Josa'),
#  ('참신한', 'Adjective'),
#  ('방법', 'Noun'),
#  ('을', 'Josa'),
#  ('구', 'Modifier'),
#  ('안해', 'Noun'),
#  ('내시길', 'Verb'),
#  ('바라며', 'Verb'),
#  ('이만', 'Adverb'),
#  ('줄입니다', 'Verb'),
#  ('장바구니', 'Noun'),
#  ('가', 'Josa'),
#  ('너무', 'Adverb'),
#  ('불편합니다', 'Adjective'),
#  ('비', 'Noun'),
#  ('마트', 'Noun'),
#  ('에서', 'Josa'),
#  ('여러가지', 'Noun'),
#  ('를', 'Josa'),
#  ('담고', 'Verb'),
#  ('스', 'Noun'),
#  ('크롤', 'Noun'),
#  ('올리고', 'Verb'),
#  ('내릴', 'Verb'),
#  ('때', 'Noun'),
#  ('살짝', 'Noun'),
#  ('대각선', 'Noun'),
#  ('으로', 'Josa'),
#  ('움직이면', 'Verb'),
#  ('배달', 'Noun'),
#  ('포장', 'Noun'),
#  ('대', 'Modifier'),
#  ('용량', 'Noun'),
#  ('특', 'Noun'),
#  ('가', 'Josa'),
#  ('등', 'Noun'),
#  ('좌우', 'Noun'),
#  ('로', 'Josa'),
#  ('넘어가', 'Verb'),
#  ('버리고', 'Verb'),
#  ('비', 'Noun'),
#  ('마트', 'Noun'),
#  ('항목', 'Noun'),
#  ('으로', 'Josa'),
#  ('다시', 'Noun'),
#  ('넘어오면', 'Verb'),
#  ('체크', 'Noun'),
#  ('해', 'Verb'),
#  ('둔', 'Verb'),
#  ('상태', 'Noun'),
#  ('가', 'Josa'),
#  ('아닌', 'Adjective'),
#  ('리', 'Noun'),
#  ('로딩', 'Noun'),
#  ('되어', 'Verb'),
#  ('맨', 'Modifier'),
#  ('위로', 'Noun'),
#  ('올라가고', 'Verb'),
#  ('전체', 'Noun'),
#  ('선택', 'Noun'),
#  ('이', 'Josa'),
#  ('됩니다', 'Verb'),
#  ('너무', 'Adverb'),
#  ('예민해서', 'Adjective'),
#  ('살짝', 'Noun'),
#  ('만', 'Josa'),
#  ('직선', 'Noun'),
#  ('에서', 'Josa'),
#  ('벗어나도', 'Verb'),
#  ('옆', 'Noun'),
#  ('항목', 'Noun'),
#  ('으로', 'Josa'),
#  ('가는데', 'Verb'),
#  ('쓸', 'Verb'),
#  ('때', 'Noun'),
#  ('마다', 'Josa'),
#  ('짜증나더라고요', 'Adjective'),
#  ('위', 'Noun'),
#  ('에', 'Josa'),
#  ('배달', 'Noun'),
#  ('포장', 'Noun'),
#  ('비', 'Noun'),
#  ('마트', 'Noun'),
#  ('대', 'Modifier'),
#  ('용량', 'Noun'),
#  ('특', 'Noun'),
#  ('가', 'Josa'),
#  ('등', 'Noun'),
#  ('항목', 'Noun'),
#  ('을', 'Josa'),
#  ('눌러서', 'Verb'),
#  ('선택', 'Noun'),
#  ('해도', 'Verb'),
#  ('될듯', 'Verb'),
#  ('한', 'Determiner'),
#  ('데', 'Noun'),
#  ('화면', 'Noun'),
#  ('을', 'Josa'),
#  ('옆', 'Noun'),
#  ('으로', 'Josa'),
#  ('넘길', 'Verb'),
#  ('필요', 'Noun'),
#  ('까진', 'Josa'),
#  ('없는듯', 'Adjective'),
#  ('합니다', 'Verb'),
#  ('거의', 'Noun'),
#  ('매일', 'Noun'),
#  ('배민', 'Noun'),
#  ('어플', 'Noun'),
#  ('사용', 'Noun'),
#  ('하면서', 'Verb'),
#  ('느낀', 'Verb'),
#  ('점', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('마트', 'Noun'),
#  ('이용', 'Noun'),
#  ('중', 'Suffix'),
#  ('인데', 'Josa'),
#  ('언제', 'Noun'),
#  ('부턴', 'Josa'),
#  ('가', 'Verb'),
#  ('전체', 'Noun'),
#  ('선택', 'Noun'),
#  ('버튼', 'Noun'),
#  ('이', 'Josa'),
#  ('비', 'Noun'),
#  ('활성화', 'Noun'),
#  ('되어있습니다', 'Verb'),
#  ('장바구니', 'Noun'),
#  ('에', 'Josa'),
#  ('있는것', 'Adjective'),
#  ('중', 'Noun'),
#  ('에', 'Josa'),
#  ('원하는걸', 'Adjective'),
#  ('구매', 'Noun'),
#  ('하려면', 'Verb'),
#  ('체크박스', 'Noun'),
#  ('를', 'Josa'),
#  ('해제', 'Noun'),
#  ('하면서', 'Verb'),
#  ('스크롤', 'Noun'),
#  ('을', 'Josa'),
#  ('내려야하고', 'Verb'),
#  ('화면', 'Noun'),
#  ('을', 'Josa'),
#  ('꾹', 'Noun'),
#  ('눌렀다', 'Verb'),
#  ('떼거나', 'Verb'),
#  ('터치', 'Noun'),
#  ('를', 'Josa'),
#  ('잘못', 'Noun'),
#  ('하면', 'Verb'),
#  ('페이지', 'Noun'),
#  ('가', 'Josa'),
#  ('새로고침', 'Noun'),
#  ('되고', 'Verb'),
#  ('선택', 'Noun'),
#  ('한', 'Determiner'),
#  ('게', 'Noun'),
#  ('초기', 'Noun'),
#  ('화', 'Suffix'),
#  ('됩니다', 'Verb'),
#  ('결제', 'Noun'),
#  ('넘어가기전에', 'Verb'),
#  ('선택', 'Noun'),
#  ('제품', 'Noun'),
#  ('이', 'Josa'),
#  ('뭔', 'Modifier'),
#  ('지', 'Modifier'),
#  ('한번', 'Noun'),
#  ('더', 'Noun'),
#  ('볼', 'Noun'),
#  ('수', 'Noun'),
#  ('있으면', 'Adjective'),
#  ('좋겠어요', 'Adjective'),
#  ('수저', 'Noun'),
#  ('포크', 'Noun'),
#  ('버튼', 'Noun'),
#  ('기본', 'Noun'),
#  ('으로', 'Josa'),
#  ('활성화', 'Noun'),
#  ('되어있는거', 'Verb'),
#  ('환경', 'Noun'),
#  ('보호', 'Noun'),
#  ('한다고', 'Verb'),
#  ('해놓은', 'Verb'),
#  ('거', 'Noun'),
#  ('압니', 'Noun'),
#  ('다', 'Josa'),
#  ('그런데', 'Conjunction'),
#  ('그거', 'Noun'),
#  ('랑', 'Josa'),
#  ('별개', 'Noun'),
#  ('로', 'Josa'),
#  ('사용자', 'Noun'),
#  ('가', 'Josa'),
#  ('기', 'Modifier'),
#  ('본', 'Modifier'),
#  ('설정', 'Noun'),
#  ('을', 'Josa'),
#  ('바꿀', 'Verb'),
#  ('수', 'Noun'),
#  ('있게', 'Adjective'),
#  ('해줘야지', 'Verb'),
#  ('결제', 'Noun'),
#  ('창', 'Noun'),
#  ('껏', 'Noun'),
#  ('다가', 'Noun'),
#  ('다시', 'Noun'),
#  ('열면', 'Verb'),
#  ('또', 'Noun'),
#  ('체크', 'Noun'),
#  ('되어있어서', 'Verb'),
#  ('조금', 'Noun'),
#  ('만', 'Josa'),
#  ('까먹으면', 'Verb'),
#  ('수저', 'Noun'),
#  ('없이', 'Adverb'),
#  ('밥', 'Noun'),
#  ('먹기', 'Noun'),
#  ('일수', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('기능', 'Noun'),
#  ('을', 'Josa'),
#  ('삭제', 'Noun'),
#  ('하는게', 'Verb'),
#  ('아니라', 'Adjective'),
#  ('디폴트', 'Noun'),
#  ('설정', 'Noun'),
#  ('을', 'Josa'),
#  ('바꿀', 'Verb'),
#  ('수', 'Noun'),
#  ('있게', 'Adjective'),
#  ('옵션', 'Noun'),
#  ('에', 'Josa'),
#  ('추가', 'Noun'),
#  ('해주세요', 'Verb'),
#  ('저', 'Noun'),
#  ('는', 'Josa'),
#  ('직장', 'Noun'),
#  ('에서', 'Josa'),
#  ('점심', 'Noun'),
#  ('먹을', 'Verb'),
#  ('때', 'Noun'),
#  ('맨손', 'Noun'),
#  ('으로', 'Josa'),
#  ('먹기', 'Noun'),
#  ('싫습니다', 'Adjective'),
#  ('이렇게', 'Adverb'),
#  ('주문', 'Noun'),
#  ('실수', 'Noun'),
#  ('때', 'Noun'),
#  ('젓가락', 'Noun'),
#  ('안', 'VerbPrefix'),
#  ('받아', 'Verb'),
#  ('봤자', 'Verb'),
#  ('결국', 'Adverb'),
#  ('먹을', 'Verb'),
#  ('방법', 'Noun'),
#  ('이', 'Josa'),
#  ('없어', 'Adjective'),
#  ('편의점', 'Noun'),
#  ('에서', 'Josa'),
#  ('하나', 'Noun'),
#  ('가져오게', 'Verb'),
#  ('만들', 'Verb'),
#  ('뿐', 'Noun'),
#  ('환경', 'Noun'),
#  ('에는', 'Josa'),
#  ('도움', 'Noun'),
#  ('이', 'Josa'),
#  ('안됩니다', 'Adjective'),
#  ('개선', 'Noun'),
#  ('이', 'Josa'),
#  ('되고', 'Verb'),
#  ('업데이트', 'Noun'),
#  ('가', 'Josa'),
#  ('된다는건', 'Verb'),
#  ('불편했던', 'Adjective'),
#  ('사항', 'Noun'),
#  ('들', 'Suffix'),
#  ('을', 'Josa'),
#  ('반영', 'Noun'),
#  ('하는것', 'Verb'),
#  ('아닌가요', 'Adjective'),
#  ('오히려', 'Noun'),
#  ('더', 'Noun'),
#  ('불편해서', 'Adjective'),
#  ('보기', 'Noun'),
#  ('가', 'Josa'),
#  ('싫을', 'Adjective'),
#  ('정도', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('너무', 'Adverb'),
#  ('불편하고', 'Adjective'),
#  ('더', 'Noun'),
#  ('조잡', 'Noun'),
#  ('스러워', 'Adjective'),
#  ('보여요', 'Verb'),
#  ('안', 'VerbPrefix'),
#  ('보이는', 'Verb'),
#  ('식당', 'Noun'),
#  ('은', 'Josa'),
#  ('일일', 'Noun'),
#  ('히', 'Adverb'),
#  ('검색', 'Noun'),
#  ('해서', 'Verb'),
#  ('찾아야하고', 'Verb'),
#  ('찾아야', 'Verb'),
#  ('나오고', 'Verb'),
#  ('그', 'Determiner'),
#  ('전', 'Noun'),
#  ('버전', 'Noun'),
#  ('이', 'Josa'),
#  ('훨씬', 'Adverb'),
#  ('편합니다', 'Adjective'),
#  ('ㅡㅡ', 'KoreanParticle'),
#  ('사용자', 'Noun'),
#  ('만', 'Josa'),
#  ('볼', 'Noun'),
#  ('수', 'Noun'),
#  ('있는', 'Adjective'),
#  ('배달', 'Noun'),
#  ('시켰던', 'Verb'),
#  ('가게', 'Noun'),
#  ('들', 'Suffix'),
#  ('에', 'Josa'),
#  ('대한', 'Noun'),
#  ('메모', 'Noun'),
#  ('기능', 'Noun'),
#  ('이랑', 'Josa'),
#  ('언제', 'Noun'),
#  ('몇번', 'Noun'),
#  ('먹었다', 'Verb'),
#  ('같은걸', 'Adjective'),
#  ('볼수있는', 'Verb'),
#  ('기능', 'Noun'),
#  ('같은게', 'Adjective'),
#  ('있었으면', 'Adjective'),
#  ('좋겠어요', 'Adjective'),
#  ('여러', 'Modifier'),
#  ('가게', 'Noun'),
#  ('에서', 'Josa'),
#  ('배달', 'Noun'),
#  ('을', 'Josa'),
#  ('자주', 'Noun'),
#  ('시켜', 'Verb'),
#  ('먹는데', 'Verb'),
#  ('조금', 'Noun'),
#  ('시간', 'Noun'),
#  ('이', 'Josa'),
#  ('지나면', 'Verb'),
#  ('그', 'Determiner'),
#  ('가게', 'Noun'),
#  ('음식', 'Noun'),
#  ('의', 'Josa'),
#  ('맛', 'Noun'),
#  ('이나', 'Josa'),
#  ('재', 'Noun'),
#  ('주문', 'Noun'),
#  ('할만', 'Verb'),
#  ('한', 'Determiner'),
#  ('집이었는지', 'Verb'),
#  ('아니었는지', 'Adjective'),
#  ('내', 'Noun'),
#  ('가', 'Josa'),
#  ('여기', 'Noun'),
#  ('서', 'Josa'),
#  ('시켜', 'Verb'),
#  ('먹어', 'Verb'),
#  ('본', 'Verb'),
#  ('집이었는지', 'Verb'),
#  ('아닌지', 'Adjective'),
#  ('기억', 'Noun'),
#  ('이', 'Josa'),
#  ('잘', 'Verb'),
#  ('안나', 'Noun'),
#  ('요', 'Josa'),
#  ('저', 'Noun'),
#  ('는', 'Josa'),
#  ('알뜰', 'Noun'),
#  ('이나', 'Josa'),
#  ('한', 'Determiner'),
#  ('집', 'Noun'),
#  ('배달', 'Noun'),
#  ('이용', 'Noun'),
#  ('을', 'Josa'),
#  ('원치않는데', 'Adjective'),
#  ('가게', 'Noun'),
#  ('검색', 'Noun'),
#  ('시', 'Noun'),
#  ('에는', 'Josa'),
#  ('가게', 'Noun'),
#  ('배달', 'Noun'),
#  ('은', 'Josa'),
#  ('선택', 'Noun'),
#  ('할수가', 'Verb'),
#  ('없네요', 'Adjective'),
#  ('뭔가', 'Noun'),
#  ('언제', 'Noun'),
#  ('부턴', 'Josa'),
#  ('가', 'Verb'),
#  ('어플', 'Noun'),
#  ('이', 'Determiner'),
#  ('용이', 'Noun'),
#  ('많이', 'Adverb'),
#  ('불편해졌습니다', 'Adjective'),
#  ('배민', 'Noun'),
#  ('을', 'Josa'),
#  ('제일', 'Noun'),
#  ('많이', 'Modifier'),
#  ('이용', 'Noun'),
#  ('했는데', 'Verb'),
#  ('고객', 'Noun'),
#  ('선택', 'Noun'),
#  ('이', 'Josa'),
#  ('아닌', 'Adjective'),
#  ('알뜰', 'Noun'),
#  ('이나', 'Josa'),
#  ('한', 'Determiner'),
#  ('집', 'Noun'),
#  ('배달', 'Noun'),
#  ('을', 'Josa'),
#  ('유도', 'Noun'),
#  ('하는거', 'Verb'),
#  ('같아', 'Adjective'),
#  ('사용', 'Noun'),
#  ('하기', 'Verb'),
#  ('꺼려', 'Verb'),
#  ('집니다', 'Verb'),
#  ('알뜰', 'Noun'),
#  ('은', 'Josa'),
#  ('싸지만', 'Verb'),
#  ('음식', 'Noun'),
#  ('이', 'Josa'),
#  ('다식', 'Noun'),
#  ('어', 'Suffix'),
#  ('서', 'Josa'),
#  ('오고', 'Verb'),
#  ('한', 'Determiner'),
#  ('집', 'Noun'),
#  ('은', 'Josa'),
#  ('배달', 'Noun'),
#  ('비면에서', 'Verb'),
#  ('부담', 'Noun'),
#  ('인데', 'Josa'),
#  ('참', 'Verb'),
#  ('불편합니다', 'Adjective'),
#  ('실시간', 'Noun'),
#  ('채팅', 'Noun'),
#  ('상담', 'Noun'),
#  ('해결', 'Noun'),
#  ('해주지도', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('하는데', 'Verb'),
#  ('없는게', 'Adjective'),
#  ('나을', 'Verb'),
#  ('것', 'Noun'),
#  ('같음', 'Adjective'),
#  ('결제', 'Noun'),
#  ('수단', 'Noun'),
#  ('변경', 'Noun'),
#  ('요청', 'Noun'),
#  ('했더니', 'Verb'),
#  ('이미', 'Adverb'),
#  ('출발', 'Noun'),
#  ('해서', 'Verb'),
#  ('변경', 'Noun'),
#  ('이', 'Josa'),
#  ('어렵다고하네요', 'Adjective'),
#  ('본인', 'Noun'),
#  ('들', 'Suffix'),
#  ('답변', 'Noun'),
#  ('확인', 'Noun'),
#  ('이', 'Josa'),
#  ('늦어서', 'Verb'),
#  ('늦게', 'Verb'),
#  ('확인', 'Noun'),
#  ('해서', 'Verb'),
#  ('가게', 'Noun'),
#  ('에서', 'Josa'),
#  ('이미', 'Adverb'),
#  ('출발', 'Noun'),
#  ('함', 'Noun'),
#  ('나', 'Noun'),
#  ('몰라라', 'Verb'),
#  ('문의', 'Noun'),
#  ('량', 'Noun'),
#  ('많아서', 'Adjective'),
#  ('답변', 'Noun'),
#  ('이', 'Josa'),
#  ('느려', 'Adjective'),
#  ('미안하다는', 'Adjective'),
#  ('말', 'Noun'),
#  ('만', 'Josa'),
#  ('반복', 'Noun'),
#  ('함', 'Noun'),
#  ('그리고', 'Conjunction'),
#  ('이미', 'Adverb'),
#  ('출발', 'Noun'),
#  ('했어도', 'Verb'),
#  ('재', 'Noun'),
#  ('주문', 'Noun'),
#  ('하고', 'Josa'),
#  ('라이더', 'Noun'),
#  ('는', 'Josa'),
#  ('안', 'VerbPrefix'),
#  ('잡히게', 'Verb'),
#  ('해서', 'Verb'),
#  ('재', 'Noun'),
#  ('처리', 'Noun'),
#  ('해줄수있는', 'Verb'),
#  ('기능', 'Noun'),
#  ('도', 'Josa'),
#  ('없나', 'Adjective'),
#  ('봄', 'Noun'),
#  ('또는', 'Adverb'),
#  ('귀찮아서', 'Adjective'),
#  ('처리', 'Noun'),
#  ('안', 'VerbPrefix'),
#  ('해줬나', 'Verb'),
#  ('그럴거면', 'Adjective'),
#  ('직접', 'Noun'),
#  ('빠르게', 'Adjective'),
#  ('해결', 'Noun'),
#  ('할수', 'Verb'),
#  ('있게', 'Adjective'),
#  ('가게', 'Noun'),
#  ('번호', 'Noun'),
#  ('라도', 'Josa'),
#  ('적어놓던가', 'Verb'),
#  ('별', 'Modifier'),
#  ('점', 'Noun'),
#  ('하나', 'Noun'),
#  ('도', 'Josa'),
#  ('아까', 'Adjective'),
#  ('움', 'Noun'),
#  ('ㅎ', 'KoreanParticle'),
#  ('배차', 'Noun'),
#  ('관리', 'Noun'),
#  ('도', 'Josa'),
#  ('못', 'Noun'),
#  ('하고', 'Josa'),
#  ('업주', 'Noun'),
#  ('한테', 'Josa'),
#  ('든', 'Verb'),
#  ('고객', 'Noun'),
#  ('한테', 'Josa'),
#  ('든', 'Verb'),
#  ('제대로', 'Noun'),
#  ('된', 'Verb'),
#  ('보상', 'Noun'),
#  ('도', 'Josa'),
#  ('없고', 'Adjective'),
#  ('채팅', 'Noun'),
#  ('으로도', 'Josa'),
#  ('전', 'Modifier'),
#  ('화로', 'Noun'),
#  ('도', 'Josa'),
#  ('상담', 'Noun'),
#  ('원', 'Suffix'),
#  ('연결', 'Noun'),
#  ('안', 'Noun'),
#  ('될거면', 'Verb'),
#  ('왜', 'Noun'),
#  ('만든', 'Verb'),
#  ('건지', 'Verb'),
#  ('등급', 'Noun'),
#  ('도', 'Josa'),
#  ('의미', 'Noun'),
#  ('없어진지', 'Verb'),
#  ('오', 'Modifier'),
#  ('래지', 'Noun'),
#  ('만', 'Josa'),
#  ('처음', 'Noun'),
#  ('부터', 'Josa'),
#  ('써', 'Verb'),
#  ('왔기에', 'Verb'),
#  ('불편한', 'Adjective'),
#  ('거', 'Noun'),
#  ('감수', 'Noun'),
#  ('하고', 'Josa'),
#  ('계속', 'Noun'),
#  ('사용', 'Noun'),
#  ('했는데', 'Verb'),
#  ('도저히', 'Noun'),
#  ('못', 'VerbPrefix'),
#  ('해', 'Verb'),
#  ('먹겠네', 'Verb'),
#  ('망하라고', 'Adjective'),
#  ('저주', 'Noun'),
#  ('안', 'Noun'),
#  ('해도', 'Noun'),
#  ('이미', 'Adverb'),
#  ('망해가는', 'Adjective'),
#  ('듯', 'Noun'),
#  ('찜', 'Noun'),
#  ('기능', 'Noun'),
#  ('에', 'Josa'),
#  ('폴더', 'Noun'),
#  ('로', 'Josa'),
#  ('분류', 'Noun'),
#  ('할', 'Verb'),
#  ('수', 'Noun'),
#  ('있는', 'Adjective'),
#  ('기능', 'Noun'),
#  ('이', 'Josa'),
#  ('있었으면', 'Adjective'),
#  ('좋겠습니다', 'Adjective'),
#  ('배달', 'Noun'),
#  ('팁', 'Noun'),
#  ('이', 'Josa'),
#  ('저렴한', 'Adjective'),
#  ('가게', 'Noun'),
#  ('맛있던', 'Adjective'),
#  ('가게', 'Noun'),
#  ('식사', 'Noun'),
#  ('목적', 'Noun'),
#  ('후식', 'Noun'),
#  ('목적', 'Noun'),
#  ('이런', 'Adjective'),
#  ('가게', 'Noun'),
#  ('들', 'Suffix'),
#  ('을', 'Josa'),
#  ('다', 'Adverb'),
#  ('찜', 'Noun'),
#  ('해놓고', 'Verb'),
#  ('사용', 'Noun'),
#  ('하고', 'Josa'),
#  ('있었는데', 'Adjective'),
#  ('수가', 'Noun'),
#  ('많아지다', 'Verb'),
#  ('보니', 'Verb'),
#  ('구분', 'Noun'),
#  ('하는', 'Verb'),
#  ('게', 'Noun'),
#  ('어려워요', 'Adjective'),
#  ('왜', 'Noun'),
#  ('배달', 'Noun'),
#  ('이', 'Josa'),
#  ('사라지고', 'Verb'),
#  ('자체', 'Noun'),
#  ('배달', 'Noun'),
#  ('이', 'Josa'),
#  ('생긴', 'Verb'),
#  ('걸까', 'Verb'),
#  ('요', 'Noun'),
#  ('이제', 'Noun'),
#  ('알뜰', 'Noun'),
#  ('이랑', 'Josa'),
#  ('한', 'Determiner'),
#  ('집', 'Noun'),
#  ('배달', 'Noun'),
#  ...]

# %%
words = []

for word, tag in okt_data:
    if tag in ['Noun', 'Adjective']:
        if len(word) > 1:
            words.append(word)              # 한글자는 제거

words
# Out:
# ['주문',
#  '취소',
#  '계속',
#  '최신',
#  '정보',
#  '로딩',
#  '반복',
#  '로딩',
#  '이미지',
#  '안정',
#  '네트워크',
#  '상황',
#  '새로고침',
#  '무한',
#  '로딩',
#  '심지어',
#  '지금',
#  '진행중',
#  '정보',
#  '정확하지',
#  '코로나',
#  '때문',
#  '서버',
#  '불안정한',
#  '취소',
#  '꼼짝',
#  '음식',
#  '하나',
#  '우리나라',
#  '국내',
#  '번호',
#  '필요함',
#  '번호',
#  '인증',
#  '필수',
#  '카드',
#  '결제',
#  '선택',
#  '다른',
#  '은행',
#  '인증',
#  '정도',
#  '해외',
#  '카드',
#  '결제',
#  '수단',
#  '아예',
#  '없고',
#  '현금',
#  '결제',
#  '옵션',
#  '없나요',
#  '음식',
#  '하나',
#  '복잡한',
#  '나라',
#  '우리나라',
#  '없습니다',
#  '강국',
#  '무슨',
#  '핸드폰',
#  '번호',
#  '인증',
#  '카드',
#  '인증',
#  '불편하게',
#  '스탭',
#  '많나요',
#  '사용',
#  '짜증나고',
#  '저녁',
#  '먹음',
#  '외국',
#  '거주',
#  '방법',
#  '없네요',
#  '해외',
#  '카드',
#  '결제',
#  '안되나요',
#  '업데이트',
#  '사용',
#  '점점',
#  '불편하게',
#  '클릭',
#  '한번',
#  '번거롭게',
#  '결제',
#  '저쪽',
#  '구석',
#  '마치',
#  '배달',
#  '유도',
#  '메인',
#  '잘못',
#  '클릭',
#  '자꾸',
#  '결제',
#  '다시',
#  '클릭',
#  '결제',
#  '요청',
#  '사항',
#  '리뷰',
#  '이벤트',
#  '클릭',
#  '쓸데없는',
#  '정말',
#  '배민',
#  '배달',
#  '민족',
#  '자체',
#  '만족하나',
#  '식사',
#  '리뷰',
#  '평점',
#  '자체',
#  '클린',
#  '같습니다',
#  '식당',
#  '입장',
#  '업주',
#  '입장',
#  '높은',
#  '인한',
#  '문건',
#  '기대하려',
#  '주문',
#  '입장',
#  '없는',
#  '식당',
#  '체적',
#  '정확한',
#  '맛집',
#  '탐색',
#  '어렵다는',
#  '자체',
#  '대한',
#  '평점',
#  '즐거운',
#  '식사',
#  '항상',
#  '추구',
#  '기대하나',
#  '평점',
#  '그러지',
#  '애석하게',
#  '생각',
#  '있습니다',
#  '수고',
#  '어플리케이션',
#  '개발자',
#  '여러분',
#  '좋은',
#  '아이디어',
#  '참신한',
#  '방법',
#  '안해',
#  '장바구니',
#  '불편합니다',
#  '마트',
#  '여러가지',
#  '크롤',
#  '살짝',
#  '대각선',
#  '배달',
#  '포장',
#  '용량',
#  '좌우',
#  '마트',
#  '항목',
#  '다시',
#  '체크',
#  '상태',
#  '아닌',
#  '로딩',
#  '위로',
#  '전체',
#  '선택',
#  '예민해서',
#  '살짝',
#  '직선',
#  '항목',
#  '짜증나더라고요',
#  '배달',
#  '포장',
#  '마트',
#  '용량',
#  '항목',
#  '선택',
#  '화면',
#  '필요',
#  '없는듯',
#  '거의',
#  '매일',
#  '배민',
#  '어플',
#  '사용',
#  '입니다',
#  '마트',
#  '이용',
#  '언제',
#  '전체',
#  '선택',
#  '버튼',
#  '활성화',
#  '장바구니',
#  '있는것',
#  '원하는걸',
#  '구매',
#  '체크박스',
#  '해제',
#  '스크롤',
#  '화면',
#  '터치',
#  '잘못',
#  '페이지',
#  '새로고침',
#  '선택',
#  '초기',
#  '결제',
#  '선택',
#  '제품',
#  '한번',
#  '있으면',
#  '좋겠어요',
#  '수저',
#  '포크',
#  '버튼',
#  '기본',
#  '활성화',
#  '환경',
#  '보호',
#  '압니',
#  '그거',
#  '별개',
#  '사용자',
#  '설정',
#  '있게',
#  '결제',
#  '다가',
#  '다시',
#  '체크',
#  '조금',
#  '수저',
#  '먹기',
#  '일수',
#  '입니다',
#  '기능',
#  '삭제',
#  '아니라',
#  '디폴트',
#  '설정',
#  '있게',
#  '옵션',
#  '추가',
#  '직장',
#  '점심',
#  '맨손',
#  '먹기',
#  '싫습니다',
#  '주문',
#  '실수',
#  '젓가락',
#  '방법',
#  '없어',
#  '편의점',
#  '하나',
#  '환경',
#  '도움',
#  '안됩니다',
#  '개선',
#  '업데이트',
#  '불편했던',
#  '사항',
#  '반영',
#  '아닌가요',
#  '오히려',
#  '불편해서',
#  '보기',
#  '싫을',
#  '정도',
#  '입니다',
#  '불편하고',
#  '조잡',
#  '스러워',
#  '식당',
#  '일일',
#  '검색',
#  '버전',
#  '편합니다',
#  '사용자',
#  '있는',
#  '배달',
#  '가게',
#  '대한',
#  '메모',
#  '기능',
#  '언제',
#  '몇번',
#  '같은걸',
#  '기능',
#  '같은게',
#  '있었으면',
#  '좋겠어요',
#  '가게',
#  '배달',
#  '자주',
#  '조금',
#  '시간',
#  '가게',
#  '음식',
#  '주문',
#  '아니었는지',
#  '여기',
#  '아닌지',
#  '기억',
#  '안나',
#  '알뜰',
#  '배달',
#  '이용',
#  '원치않는데',
#  '가게',
#  '검색',
#  '가게',
#  '배달',
#  '선택',
#  '없네요',
#  '뭔가',
#  '언제',
#  '어플',
#  '용이',
#  '불편해졌습니다',
#  '배민',
#  '제일',
#  '이용',
#  '고객',
#  '선택',
#  '아닌',
#  '알뜰',
#  '배달',
#  '유도',
#  '같아',
#  '사용',
#  '알뜰',
#  '음식',
#  '다식',
#  '배달',
#  '부담',
#  '불편합니다',
#  '실시간',
#  '채팅',
#  '상담',
#  '해결',
#  '없는게',
#  '같음',
#  '결제',
#  '수단',
#  '변경',
#  '요청',
#  '출발',
#  '변경',
#  '어렵다고하네요',
#  '본인',
#  '답변',
#  '확인',
#  '확인',
#  '가게',
#  '출발',
#  '문의',
#  '많아서',
#  '답변',
#  '느려',
#  '미안하다는',
#  '반복',
#  '출발',
#  '주문',
#  '라이더',
#  '처리',
#  '기능',
#  '없나',
#  '귀찮아서',
#  '처리',
#  '그럴거면',
#  '직접',
#  '빠르게',
#  '해결',
#  '있게',
#  '가게',
#  '번호',
#  '하나',
#  '아까',
#  '배차',
#  '관리',
#  '업주',
#  '고객',
#  '제대로',
#  '보상',
#  '없고',
#  '채팅',
#  '화로',
#  '상담',
#  '연결',
#  '등급',
#  '의미',
#  '래지',
#  '처음',
#  '불편한',
#  '감수',
#  '계속',
#  '사용',
#  '도저히',
#  '망하라고',
#  '저주',
#  '해도',
#  '망해가는',
#  '기능',
#  '폴더',
#  '분류',
#  '있는',
#  '기능',
#  '있었으면',
#  '좋겠습니다',
#  '배달',
#  '저렴한',
#  '가게',
#  '맛있던',
#  '가게',
#  '식사',
#  '목적',
#  '후식',
#  '목적',
#  '이런',
#  '가게',
#  '사용',
#  '있었는데',
#  '수가',
#  '구분',
#  '어려워요',
#  '배달',
#  '자체',
#  '배달',
#  '이제',
#  '알뜰',
#  '배달',
#  '가요',
#  '일반',
#  '배달',
#  '없는건',
#  '가요',
#  '화면',
#  '직접',
#  '설정',
#  '있는',
#  '기능',
#  '있으면',
#  '좋을',
#  '같네요',
#  '치킨',
#  '검색',
#  '많은',
#  '중간',
#  '갯수',
#  '낮은',
#  '가게',
#  '뭔가',
#  '많은',
#  '순이',
#  '많은',
#  '순이',
#  '아니게',
#  '광고',
#  '해도',
#  '심합니다',
#  '편의점',
#  '갑자기',
#  '기타',
#  '사유',
#  '주문',
#  '취소',
#  '평소',
#  '워낙',
#  '친절한',
#  '매장',
#  '무슨',
#  '일이',
#  '전화',
#  '매장',
#  '아니라',
#  '편의점',
#  '고객',
#  '센터',
#  '연결',
#  '심지어',
#  '주말',
#  '고객',
#  '센터',
#  '계속',
#  '나가야',
#  '이제',
#  '다른',
#  '수도',
#  '없고요',
#  '바쁠',
#  '수도',
#  '있고',
#  '재고',
#  '없을',
#  '수도',
#  '있는',
#  '이해',
#  '평소',
#  '친절하게',
#  '대응',
#  '매장',
#  '다만',
#  '취소',
#  '안되는지',
#  '정확한',
#  '사유',
#  '좋겠어요',
#  '편의점',
#  '부족한',
#  '있을',
#  '부분',
#  '취소',
#  '안되는',
#  '안된다면',
#  '이런',
#  '점도',
#  '개선',
#  '좋겠어요',
#  '래야',
#  '서로',
#  '편할거',
#  '같아요',
#  '배민',
#  '이용',
#  '생각',
#  '가게',
#  '차단',
#  '있는',
#  '기능',
#  '같은게',
#  '생기',
#  '좋겠어요',
#  '단골',
#  '식당',
#  '휴일',
#  '식당',
#  '주문',
#  '있었어요',
#  '기억',
#  '한참',
#  '시간',
#  '지나',
#  '깜박',
#  '실수',
#  '주문',
#  '자주',
#  '아니니까',
#  '식당',
#  '차단',
#  '기능',
#  '반대',
#  '기능',
#  '같은',
#  '다른건',
#  '괜찮은데',
#  '위아래',
#  '크롤',
#  '계속',
#  '잘못',
#  '인식',
#  '마트',
#  '물건',
#  '계속',
#  '포장',
#  '이동',
#  '매우',
#  '시티',
#  '개선',
#  '필요해',
#  '불편해요',
#  '짜증나요',
#  '진짜',
#  '개열',
#  '디폴트',
#  '수저',
#  '결제',
#  '방법',
#  '변경',
#  '오류로',
#  '다시',
#  '결제',
#  '수저',
#  '포크',
#  '아주',
#  '짜증나네요',
#  '체크',
#  '결제',
#  '다시',
#  '시도',
#  '진짜',
#  '짜증나요',
#  '짜증나서',
#  '후기',
#  '배민',
#  '배달',
#  '도착',
#  '주문',
#  '도착',
#  '커녕',
#  '배차',
#  '이런',
#  '아님',
#  '예상',
#  '시간',
#  '똑바로',
#  '배달',
#  '시스템',
#  '자체',
#  '주문',
#  '도착',
#  '정시',
#  '점점',
#  '기존',
#  '혜택',
#  '아니였는데',
#  '브랜드',
#  '쿠폰',
#  '사용',
#  '이해',
#  '없네요',
#  '그것',
#  '아무런',
#  '공지',
#  '갑작스럽게',
#  '브랜드',
#  '자체',
#  '쿠폰',
#  '겨우',
#  '천원',
#  '할인',
#  '누가',
#  '좋아한다고',
#  '혜택',
#  '생기',
#  '한번',
#  '없을',
#  '정도',
#  '정말',
#  '배민',
#  '사용',
#  '사용',
#  '마음',
#  '원래',
#  '최소',
#  '주문',
#  '금액',
#  '이상',
#  '주문',
#  '사용',
#  '지금',
#  '최소',
#  '금액',
#  '브랜드',
#  '일주일',
#  '아니라',
#  '혜택',
#  '쿠폰',
#  '메뉴',
#  '정해',
#  '야하면',
#  '굳이',
#  '배민',
#  '혜택',
#  '없는데',
#  '사용',
#  '필요',
#  '있나요',
#  '어플',
#  '진짜',
#  '가면',
#  '갈수록',
#  '심하네요',
#  '아니',
#  '전화',
#  '해결',
#  '계속',
#  '전화하래',
#  '배민',
#  '스토어',
#  '리뷰',
#  '이상',
#  '사진',
#  '첨부',
#  '체크',
#  '표시',
#  '정립',
#  '전화',
#  '문의',
#  '상담사',
#  '문제',
#  '본인',
#  '잘못',
#  '정립',
#  '이럴',
#  '가이드라인',
#  '지난번',
#  '다른',
#  '상품',
#  '리뷰',
#  '이상',
#  '정립',
#  '전화해서',
#  '정립',
#  '이번',
#  '해결',
#  '배민',
#  '거의',
#  '매일',
#  '해먹',
#  '여러가지',
#  '메뉴',
#  '가게',
#  '군데',
#  '주문',
#  '있고',
#  '하루',
#  '이용',
#  '있어서',
#  '항상',
#  '제일',
#  '높은',
#  '등급',
#  '천생연분',
#  '입니다',
#  '천생연분',
#  '혜택',
#  '천원',
#  '쿠폰',
#  '장천',
#  '쿠폰',
#  '최소',
#  '주문',
#  '금액',
#  '있게',
#  '혜택',
#  '생각',
#  '부터',
#  '배민',
#  '다른',
#  '배달',
#  '플로',
#  '생각',
#  '없었고',
#  '배달',
#  '인상',
#  '여러가지',
#  '이슈',
#  '계속',
#  '이용',
#  '이번',
#  '처음',
#  '진짜',
#  '다른',
#  '배달',
#  '플로',
#  '생각',
#  '그래도',
#  '많지도',
#  '혜택',
#  '쿠폰',
#  '브랜드',
#  '쿠폰',
#  '배민',
#  '자주',
#  '이용',
#  '있는',
#  '혜택',
#  '하나',
#  '없습니다',
#  '가요',
#  '여러',
#  '이용자',
#  '넓은',
#  '혜택',
#  '주기',
#  '라지',
#  '이건',
#  '이용자',
#  '누구',
#  '좋을게',
#  '없다고',
#  '생각',
#  '쿠폰',
#  '천원',
#  '배민',
#  '지정',
#  '브랜드',
#  '음식',
#  '주문',
#  '하란',
#  '이제',
#  '배민',
#  '이용',
#  '진심',
#  '짜증나네요',
#  '사용',
#  '불편하게',
#  '무슨',
#  '음식',
#  '주문',
#  '복잡하게',
#  '이벤트',
#  '이벤트',
#  '대로',
#  '배달',
#  '배달',
#  '포장',
#  '포장',
#  '지도',
#  '지도',
#  '대로',
#  '편하게',
#  '만듭시',
#  '개발자',
#  '내부',
#  '적도',
#  '아니고',
#  '복잡하노',
#  '요기',
#  '요가',
#  '편하네',
#  '배달',
#  '거지',
#  '도저히',
#  '없는',
#  '상태',
#  '환불',
#  '요청',
#  '음식물',
#  '수거',
#  '지시',
#  '환불',
#  '요청',
#  '수거',
#  '지시',
#  '채팅',
#  '문의',
#  '응대',
#  '음식점',
#  '배달',
#  '기사',
#  '하나',
#  '잘못',
#  '환불',
#  '시간',
#  '소모',
#  '감정',
#  '소모',
#  '채팅',
#  '상담',
#  '전화',
#  '상담',
#  '무슨',
#  '수거',
#  '지시',
#  '배차',
#  '이중',
#  '전달',
#  '두번째',
#  '기사',
#  '음식',
#  '굉장히',
#  '당혹스러웠음',
#  '거주',
#  '입장',
#  '문밖',
#  '갑자기',
#  '이유',
#  '얼마나',
#  '당황',
#  '스럽겠습니까',
#  '처음',
#  '거지같은',
#  '사용자',
#  '경험',
#  '연속',
#  '쿠폰',
#  '시로',
#  '뿌리',
#  '가끔',
#  '이벤트',
#  '쿠폰',
#  '더하면',
#  '포장',
#  '방문',
#  '배달',
#  '있어서',
#  '편리하고',
#  '좋은',
#  '같아요',
#  '한가지',
#  '아쉬운',
#  '거의',
#  '모든',
#  '가게',
#  '최소',
#  '금액',
#  '가까이',
#  '혼자',
#  '주문',
#  '부담',
#  '인분',
#  '기능',
#  '있긴하지만',
#  '원하는',
#  '음식점',
#  '항상',
#  '인분',
#  '기능',
#  '포함',
#  '안되어',
#  '있어서',
#  '항상',
#  '포장',
#  '방문',
#  '이용',
#  '같아요',
#  '다른',
#  '필요없고',
#  '메뉴',
#  '장바구느',
#  '기능',
#  '장바구니',
#  '저장',
#  '기능',
#  '안될까',
#  '빵집',
#  '종류',
#  '다양해서',
#  '하나',
#  '하나',
#  '장바구니',
#  '다른',
#  '빵집',
#  '어떤',
#  '다시',
#  '야하는',
#  '번거로운',
#  '때문',
#  '장바구니',
#  '메뉴',
#  '장기',
#  '능이',
#  '있으면',
#  '메뉴',
#  '그대로',
#  '있었으면',
#  '좋겠습니다',
#  '업데이트',
#  '불편함',
#  '사람',
#  '위치',
#  '방식',
#  '주문',
#  '인터페이스',
#  '자꾸',
#  '기능',
#  '추가',
#  '오지',
#  '클릭',
#  '위치',
#  '빡침',
#  '요기',
#  '요로',
#  '사람',
#  '많음',
#  '응대',
#  '수준',
#  '심각하네요',
#  '문의량',
#  '많다는',
#  '이유',
#  '접수',
#  '정시',
#  '도착',
#  '취소',
#  '전화',
#  '안되고',
#  '채팅',
#  '안되면',
#  '이런',
#  '상황',
#  '발생',
#  '어떻게',
#  '대처',
#  '러시',
#  ...]

# %%
# 불용어 제거 집합 만들기

stop_words = '배달 민족 주문 가게'
stop_words = set(stop_words.split())
stop_words
# Out:
# {'가게', '민족', '배달', '주문'}

# %%
# stop words 제거
word_data = []

# 불용어 제거
for temp in words:
    if not temp in stop_words:
        word_data.append(temp)

# 최종 불용어 제거 후 단어 리스트의 길이 출력
len(word_data)
# Out:
# 12004

# %%
# 단어 빈도수 계산
count_data = Counter(word_data)

# 가장 많이 등장하는 100개의 단어 추출
c_data = count_data.most_common(100)
c_data
# Out:
# [('시간', 195),
#  ('배민', 172),
#  ('메뉴', 142),
#  ('기능', 109),
#  ('고객', 107),
#  ('리뷰', 105),
#  ('사용', 101),
#  ('취소', 99),
#  ('음식', 99),
#  ('결제', 97),
#  ('어플', 93),
#  ('전화', 79),
#  ('검색', 77),
#  ('센터', 77),
#  ('다른', 71),
#  ('업데이트', 68),
#  ('이용', 67),
#  ('연결', 66),
#  ('쿠폰', 66),
#  ('계속', 61),
#  ('문제', 57),
#  ('다시', 55),
#  ('입니다', 55),
#  ('그냥', 55),
#  ('있는', 53),
#  ('선택', 50),
#  ('진짜', 50),
#  ('생각', 49),
#  ('상담', 49),
#  ('하나', 47),
#  ('화면', 46),
#  ('확인', 46),
#  ('좋겠습니다', 46),
#  ('추가', 45),
#  ('요청', 43),
#  ('있습니다', 43),
#  ('개선', 43),
#  ('같은', 43),
#  ('매장', 42),
#  ('설정', 41),
#  ('기본', 39),
#  ('경우', 39),
#  ('식당', 38),
#  ('사항', 37),
#  ('같습니다', 37),
#  ('사람', 37),
#  ('배차', 36),
#  ('삭제', 34),
#  ('라이더', 34),
#  ('서비스', 34),
#  ('포장', 33),
#  ('채팅', 33),
#  ('사진', 33),
#  ('있으면', 32),
#  ('이런', 32),
#  ('같아요', 32),
#  ('기사', 32),
#  ('정말', 31),
#  ('지연', 31),
#  ('연락', 31),
#  ('알뜰', 30),
#  ('시스템', 30),
#  ('정도', 29),
#  ('없고', 29),
#  ('직접', 29),
#  ('할인', 29),
#  ('지도', 29),
#  ('버튼', 28),
#  ('좋겠어요', 28),
#  ('문의', 28),
#  ('처음', 28),
#  ('이상', 28),
#  ('음식점', 28),
#  ('사용자', 27),
#  ('한번', 26),
#  ('자체', 26),
#  ('해도', 26),
#  ('별로', 26),
#  ('있게', 25),
#  ('위치', 25),
#  ('안되고', 25),
#  ('목록', 25),
#  ('무슨', 24),
#  ('부분', 24),
#  ('이유', 24),
#  ('바로', 24),
#  ('보고', 24),
#  ('로그인', 24),
#  ('입력', 24),
#  ('때문', 23),
#  ('항상', 23),
#  ('아니라', 23),
#  ('자주', 23),
#  ('답변', 23),
#  ('이제', 23),
#  ('같네요', 23),
#  ('광고', 23),
#  ('혜택', 23),
#  ('이번', 23),
#  ('있는데', 23)]

# %%
dict(c_data)
# Out:
# {'시간': 195,
#  '배민': 172,
#  '메뉴': 142,
#  '기능': 109,
#  '고객': 107,
#  '리뷰': 105,
#  '사용': 101,
#  '취소': 99,
#  '음식': 99,
#  '결제': 97,
#  '어플': 93,
#  '전화': 79,
#  '검색': 77,
#  '센터': 77,
#  '다른': 71,
#  '업데이트': 68,
#  '이용': 67,
#  '연결': 66,
#  '쿠폰': 66,
#  '계속': 61,
#  '문제': 57,
#  '다시': 55,
#  '입니다': 55,
#  '그냥': 55,
#  '있는': 53,
#  '선택': 50,
#  '진짜': 50,
#  '생각': 49,
#  '상담': 49,
#  '하나': 47,
#  '화면': 46,
#  '확인': 46,
#  '좋겠습니다': 46,
#  '추가': 45,
#  '요청': 43,
#  '있습니다': 43,
#  '개선': 43,
#  '같은': 43,
#  '매장': 42,
#  '설정': 41,
#  '기본': 39,
#  '경우': 39,
#  '식당': 38,
#  '사항': 37,
#  '같습니다': 37,
#  '사람': 37,
#  '배차': 36,
#  '삭제': 34,
#  '라이더': 34,
#  '서비스': 34,
#  '포장': 33,
#  '채팅': 33,
#  '사진': 33,
#  '있으면': 32,
#  '이런': 32,
#  '같아요': 32,
#  '기사': 32,
#  '정말': 31,
#  '지연': 31,
#  '연락': 31,
#  '알뜰': 30,
#  '시스템': 30,
#  '정도': 29,
#  '없고': 29,
#  '직접': 29,
#  '할인': 29,
#  '지도': 29,
#  '버튼': 28,
#  '좋겠어요': 28,
#  '문의': 28,
#  '처음': 28,
#  '이상': 28,
#  '음식점': 28,
#  '사용자': 27,
#  '한번': 26,
#  '자체': 26,
#  '해도': 26,
#  '별로': 26,
#  '있게': 25,
#  '위치': 25,
#  '안되고': 25,
#  '목록': 25,
#  '무슨': 24,
#  '부분': 24,
#  '이유': 24,
#  '바로': 24,
#  '보고': 24,
#  '로그인': 24,
#  '입력': 24,
#  '때문': 23,
#  '항상': 23,
#  '아니라': 23,
#  '자주': 23,
#  '답변': 23,
#  '이제': 23,
#  '같네요': 23,
#  '광고': 23,
#  '혜택': 23,
#  '이번': 23,
#  '있는데': 23}

# %%
import matplotlib.pyplot as plt

font_path = 'C:/Windows/Fonts/malgun.ttf'

word_cloud = WordCloud(
    font_path=font_path,            # 한글 폰트 경로
    background_color='black',       # 워드클라우드 배경색
    max_font_size=400,              # 최대 폰트 크기 설정
    colormap='coolwarm'             # 워드클라우드의 색상 팔레트 설정
).generate_from_frequencies(dict(c_data))

plt.imshow(word_cloud, interpolation='bilinear')    # bilinear 보간법으로 부드럽게 표시
plt.axis('off')
plt.show()
