# %%
from langchain_community.document_loaders import PyPDFLoader

# PDF 파일 처리
pdf_path = 'data2/스마트팜 질의응답.pdf'    # pdf 파일 경로 입력
loader = PyPDFLoader(pdf_path)            # pdf 파일 읽기
documents = loader.load()

documents
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_37736\2026426063.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# [Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-06-05T00:06:58+09:00', 'author': '\\Ü(', 'moddate': '2025-06-05T00:06:58+09:00', 'title': '¤È¸˝ ÈXQõ.txt - T¨¥', 'source': 'data2/스마트팜 질의응답.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Q: [교육] 스마트팜과 관련한 교육을 받고 싶습니다. 교육일정은 어디에서 확인할 수 있나요?\nA: 홈페이지 메인화면 상단의 [지원사업 및 교육정보 > 스마트팜 교육정보]에서 확인하실 수 있습\n니다. 또한, 농업교육포털(www.agriedu.net), 농촌인적자원개발센터(hrd.rda.go.kr) 참조 및 현장지\n원센터 안내에 표기된 농업기술원으로 부탁드립니다.\nQ: [현장지원센터] 스마트 팜 현장지원센터란?\nA: 스마트 팜 현장지원센터는 스마트팜 시설 설치 농가의 활용도 제고를 위해 시·군농업기술센터, \n도농업기술원 내 운영되는 기관입니다.\nQ: [현장지원센터] 권역별 스마트 팜 현장지원센터는 어디에 있나요?\nA: 현재 광주광역시, 경기, 강원, 충북, 충남, 전북, 전남, 경북, 경남, 제주까지 총 10개소로 운영중입\n니다.')]

# %%
from langchain_community.document_loaders import WebBaseLoader

website_loader = WebBaseLoader("https://www.rda.go.kr/webzine/2022/12/sub1-7.html")
website_documents = website_loader.load()
print(website_documents)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# [Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='\n\n\n\n그린매거진\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n테마 에세이\n테마 스토리\n테마 연구소\n테마 인터뷰 1\n테마 인터뷰 2\n테마 인포\n테마 Q&A\n\n\n\n\n\n테마 Q&A\n\n테마 에세이\n테마 스토리\n테마 연구소\n테마 인터뷰 1\n테마 인터뷰 2\n테마 인포\n테마 Q&A\n\n\n\n\n\n농업도 스마트하게! 스마트농업이란?\n\n정리 ㅣ 편집부자료 ㅣ 농촌진흥청\n\n\n\r\n\t\t\t\t\t우리 생활 전반에 스마트(Smart)라는 단어가 붙는 건 더 이상 낯선 일이 아니다. \r\n\t\t\t\t\t소비자들이 한층 편리하게 일하고 생활할 수 있도록 하는 기술로, \r\n\t\t\t\t\t이제는 개개인의 성향이나 생활패턴까지 반영한 스마트 기술이 개발·보급되고 있다. \r\n\t\t\t\t\t농업 분야 역시 스마트농업, 스마트팜 기술이 개발되며 \r\n\t\t\t\t\t농업 현장에서 겪는 어려움을 없애고 기술력 자체로 세계적인 경쟁력을 갖춰나가고 있다. \n스마트농업에 대한 궁금증을 풀어본다.\n\n\n\n\n\n\r\n\t\t\t\t\t테마 Q&A \r\n\t\t\t\t\n\n\nQ. 스마트농업, 스마트팜 정의가 궁금합니다.\n\r\n\t\t\t\t\t스마트농업은 농업 분야에 정보통신기술(ICT)을 접목해 농축산물과 식품 생산은 물론 유통, 판매, 소비에 이르는 농업 전 과정에 대한 생태계를 구축할 수 있는 기술입니다. 스마트팜은 센서, 정보통신기술, 기기제어, 빅데이터 등으로 복합환경제어를 자동으로 할 수 있는 시설농업기술입니다. 즉, 스마트농업이 농업 전체를 의미한다면 스마트팜은 시설농업기술을 뜻합니다.\r\n\t\t\t\t\n\n\nQ. 스마트농업은 왜 필요한가요?\n\r\n\t\t\t\t\t스마트농업은 지속 가능한 농업을 실현하는 방법 중 하나입니다. 현재 농업은 기후변화, 고령화, 농촌소멸 등으로 어려움을 겪고 있습니다. 로봇, 드론, 자율주행 등 자동화 기술을 도입하면 한층 편리하게 농작업을 할 수 있고, 작물 생산성을 높일 수 있습니다. \r\n\t\t\t\t\n\n\nQ. 우리나라 스마트팜 기술은 어느 수준인가요?  \n\r\n\t\t\t\t\t스마트팜은 단계적으로 발전해 왔습니다. 1세대는 정보통신기술을 활용해 시설 환경정보를 모니터링하고 스마트폰으로 원격 제어하는 수준입니다. 2세대는 빅데이터와 인공지능, 사물인터넷을 활용해 정밀한 생육관리가 가능한 단계이며, 3세대는 사람이 개입하지 않고 전주기 자동관리가 가능한 지능형 로봇 농장을 뜻합니다. 현재 우리나라는 3세대 스마트팜 기술을 현장에 도입하는 단계까지 발전했습니다. \r\n\t\t\t\t\n\n\nQ. 대표적인 우리나라 스마트농업 기술을 소개해 주세요. \n\r\n\t\t\t\t\t3세대 스마트팜 기술을 적용한 스마트 온실 방제 로봇이 있습니다. 방제로봇은 8시간 이상 연속 운전이 가능하고, 300L 약액통을 장착해 1회 0.33ha를 방제할 수 있습니다. 또한 마그네틱, 근접 센서, 광학 검출기 등을 사용해 계획된 경로를 따라 자율주행할 수 있도록 설정했습니다. 이와 함께 작업자가 직접 기계를 다루지 않아도 지형 환경을 인식해 스스로 주행하며 농작업이 가능한 자율주행 트랙터를 비롯해 자율주행 벼 이앙기, 로봇 착유기 국산화 등 스마트농업 기술이 개발되었습니다. 현재 방제 로봇은 토마토농장에서 현장실증 중이며, 자율주행 트랙터 등은 현장 보급을 위해 노력하고 있습니다.\r\n\t\t\t\t\n\n\nQ. 스마트농업 기술을 도입했을 시 어떤 효과가 있었나요? \n\r\n\t\t\t\t\t스마트팜을 설치하여 온실 환경, 생육, 생산량 데이터를 수집한 결과, 생산성이 토마토 농장은 13.7%, 딸기 농장은 30% 높아졌습니다. 또한 자율주행 벼 이앙기를 사용하면 노동력을 50% 가량 줄일 수 있습니다. 드론으로 방제할 경우 노동력은 87%, 농약이 날아서 흩어지는 양은 30% 가량 줄어든 것으로 나타났습니다. 그동안 해외에서 수입해 온 로봇 착유기는 국산화에 성공함으로써 외국산 대비 설치비를 60% 줄이는 효과를 냈습니다. \r\n\t\t\t\t\n\n\nQ. 앞으로 어떤 스마트농업 기술을 만나볼 수 있을까요? \n\r\n\t\t\t\t\t현재 수확·운반 로봇, 과수원 농약방제 로봇, 제초 로봇, 가축분뇨 청소 로봇 등을 개발하고 있습니다. 무인자율작업인 레벨4 수준으로 발전하기 위해 자율주행 기술 고도화, 노지 데이터 수집, 지능형 농작업기계 개발 등 스마트농업 기술 실현에 최선을 다할 계획입니다. \r\n\t\t\t\t\n\n\n\n\n\n\n\n\n\n')]

# %%
# 흩어진 Document 합치기
full_text = ""

for doc in documents:
    full_text += doc.page_content + "\n"

print(full_text)
# Out:
# Q: [교육] 스마트팜과 관련한 교육을 받고 싶습니다. 교육일정은 어디에서 확인할 수 있나요?
# A: 홈페이지 메인화면 상단의 [지원사업 및 교육정보 > 스마트팜 교육정보]에서 확인하실 수 있습
# 니다. 또한, 농업교육포털(www.agriedu.net), 농촌인적자원개발센터(hrd.rda.go.kr) 참조 및 현장지
# 원센터 안내에 표기된 농업기술원으로 부탁드립니다.
# Q: [현장지원센터] 스마트 팜 현장지원센터란?
# A: 스마트 팜 현장지원센터는 스마트팜 시설 설치 농가의 활용도 제고를 위해 시·군농업기술센터,
# 도농업기술원 내 운영되는 기관입니다.
# Q: [현장지원센터] 권역별 스마트 팜 현장지원센터는 어디에 있나요?
# A: 현재 광주광역시, 경기, 강원, 충북, 충남, 전북, 전남, 경북, 경남, 제주까지 총 10개소로 운영중입
# 니다.

# %%
import re
from langchain_core.documents import Document

pattern = r"Q:.*?\nA:.*?(?=\nQ:|\Z)"  # Q: ~ A: ~ 다음 Q: 전까지

matches = re.findall(pattern, full_text, re.DOTALL)

# Document 객체로 변환
qa_documents = []

for chunk in matches:    
    clean_text = chunk.strip()  # 앞뒤 공백 제거        
    doc = Document(page_content=clean_text)  # LangChain용 문서 객체로 감싸기
    qa_documents.append(doc)  # 리스트에 추가

qa_documents
# Out:
# [Document(metadata={}, page_content='Q: [교육] 스마트팜과 관련한 교육을 받고 싶습니다. 교육일정은 어디에서 확인할 수 있나요?\nA: 홈페이지 메인화면 상단의 [지원사업 및 교육정보 > 스마트팜 교육정보]에서 확인하실 수 있습\n니다. 또한, 농업교육포털(www.agriedu.net), 농촌인적자원개발센터(hrd.rda.go.kr) 참조 및 현장지\n원센터 안내에 표기된 농업기술원으로 부탁드립니다.'),
#  Document(metadata={}, page_content='Q: [현장지원센터] 스마트 팜 현장지원센터란?\nA: 스마트 팜 현장지원센터는 스마트팜 시설 설치 농가의 활용도 제고를 위해 시·군농업기술센터, \n도농업기술원 내 운영되는 기관입니다.'),
#  Document(metadata={}, page_content='Q: [현장지원센터] 권역별 스마트 팜 현장지원센터는 어디에 있나요?\nA: 현재 광주광역시, 경기, 강원, 충북, 충남, 전북, 전남, 경북, 경남, 제주까지 총 10개소로 운영중입\n니다.')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 텍스트 분할
text_splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n", "\n", "Q:", "A:"],  # 단락, 줄바꿈, Q/A 기준 모두 활용
    chunk_size=200,       # Q&A 1~2쌍이 들어갈 정도
    chunk_overlap=50,     # 중요한 문장이 끊기지 않도록 약간의 겹침 유지
)

texts = text_splitter.split_documents(website_documents)
print(f"총 {len(texts)}개의 텍스트 청크로 분할되었습니다.")
# Out:
# 총 14개의 텍스트 청크로 분할되었습니다.

# %%
texts
# Out:
# [Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='그린매거진\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n테마 에세이\n테마 스토리\n테마 연구소\n테마 인터뷰 1\n테마 인터뷰 2\n테마 인포\n테마 Q&A\n\n\n\n\n\n테마 Q&A\n\n테마 에세이\n테마 스토리\n테마 연구소\n테마 인터뷰 1\n테마 인터뷰 2\n테마 인포\n테마 Q&A\n\n\n\n\n\n농업도 스마트하게! 스마트농업이란?\n\n정리 ㅣ 편집부자료 ㅣ 농촌진흥청'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='우리 생활 전반에 스마트(Smart)라는 단어가 붙는 건 더 이상 낯선 일이 아니다. \r\n\t\t\t\t\t소비자들이 한층 편리하게 일하고 생활할 수 있도록 하는 기술로, \r\n\t\t\t\t\t이제는 개개인의 성향이나 생활패턴까지 반영한 스마트 기술이 개발·보급되고 있다. \r\n\t\t\t\t\t농업 분야 역시 스마트농업, 스마트팜 기술이 개발되며'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='농업 분야 역시 스마트농업, 스마트팜 기술이 개발되며 \r\n\t\t\t\t\t농업 현장에서 겪는 어려움을 없애고 기술력 자체로 세계적인 경쟁력을 갖춰나가고 있다. \n스마트농업에 대한 궁금증을 풀어본다.'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='테마 Q&A'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='Q. 스마트농업, 스마트팜 정의가 궁금합니다.'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='\n\t\t\t\t\t스마트농업은 농업 분야에 정보통신기술(ICT)을 접목해 농축산물과 식품 생산은 물론 유통, 판매, 소비에 이르는 농업 전 과정에 대한 생태계를 구축할 수 있는 기술입니다. 스마트팜은 센서, 정보통신기술, 기기제어, 빅데이터 등으로 복합환경제어를 자동으로 할 수 있는 시설농업기술입니다. 즉, 스마트농업이 농업 전체를 의미한다면 스마트팜은 시설농업기술을 뜻합니다.\r'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='Q. 스마트농업은 왜 필요한가요?\n\r\n\t\t\t\t\t스마트농업은 지속 가능한 농업을 실현하는 방법 중 하나입니다. 현재 농업은 기후변화, 고령화, 농촌소멸 등으로 어려움을 겪고 있습니다. 로봇, 드론, 자율주행 등 자동화 기술을 도입하면 한층 편리하게 농작업을 할 수 있고, 작물 생산성을 높일 수 있습니다.'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='Q. 우리나라 스마트팜 기술은 어느 수준인가요?'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='\n\t\t\t\t\t스마트팜은 단계적으로 발전해 왔습니다. 1세대는 정보통신기술을 활용해 시설 환경정보를 모니터링하고 스마트폰으로 원격 제어하는 수준입니다. 2세대는 빅데이터와 인공지능, 사물인터넷을 활용해 정밀한 생육관리가 가능한 단계이며, 3세대는 사람이 개입하지 않고 전주기 자동관리가 가능한 지능형 로봇 농장을 뜻합니다. 현재 우리나라는 3세대 스마트팜 기술을 현장에 도입하는 단계까지 발전했습니다. \r'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='Q. 대표적인 우리나라 스마트농업 기술을 소개해 주세요.'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='\n\t\t\t\t\t3세대 스마트팜 기술을 적용한 스마트 온실 방제 로봇이 있습니다. 방제로봇은 8시간 이상 연속 운전이 가능하고, 300L 약액통을 장착해 1회 0.33ha를 방제할 수 있습니다. 또한 마그네틱, 근접 센서, 광학 검출기 등을 사용해 계획된 경로를 따라 자율주행할 수 있도록 설정했습니다. 이와 함께 작업자가 직접 기계를 다루지 않아도 지형 환경을 인식해 스스로 주행하며 농작업이 가능한 자율주행 트랙터를 비롯해 자율주행 벼 이앙기, 로봇 착유기 국산화 등 스마트농업 기술이 개발되었습니다. 현재 방제 로봇은 토마토농장에서 현장실증 중이며, 자율주행 트랙터 등은 현장 보급을 위해 노력하고 있습니다.\r'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='Q. 스마트농업 기술을 도입했을 시 어떤 효과가 있었나요?'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='\n\t\t\t\t\t스마트팜을 설치하여 온실 환경, 생육, 생산량 데이터를 수집한 결과, 생산성이 토마토 농장은 13.7%, 딸기 농장은 30% 높아졌습니다. 또한 자율주행 벼 이앙기를 사용하면 노동력을 50% 가량 줄일 수 있습니다. 드론으로 방제할 경우 노동력은 87%, 농약이 날아서 흩어지는 양은 30% 가량 줄어든 것으로 나타났습니다. 그동안 해외에서 수입해 온 로봇 착유기는 국산화에 성공함으로써 외국산 대비 설치비를 60% 줄이는 효과를 냈습니다. \r'),
#  Document(metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='Q. 앞으로 어떤 스마트농업 기술을 만나볼 수 있을까요? \n\r\n\t\t\t\t\t현재 수확·운반 로봇, 과수원 농약방제 로봇, 제초 로봇, 가축분뇨 청소 로봇 등을 개발하고 있습니다. 무인자율작업인 레벨4 수준으로 발전하기 위해 자율주행 기술 고도화, 노지 데이터 수집, 지능형 농작업기계 개발 등 스마트농업 기술 실현에 최선을 다할 계획입니다.')]

# %%
texts[0].page_content
# Out:
# '그린매거진\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n테마 에세이\n테마 스토리\n테마 연구소\n테마 인터뷰 1\n테마 인터뷰 2\n테마 인포\n테마 Q&A\n\n\n\n\n\n테마 Q&A\n\n테마 에세이\n테마 스토리\n테마 연구소\n테마 인터뷰 1\n테마 인터뷰 2\n테마 인포\n테마 Q&A\n\n\n\n\n\n농업도 스마트하게! 스마트농업이란?\n\n정리 ㅣ 편집부자료 ㅣ 농촌진흥청'

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS



# 벡터 스토어 생성
# 텍스트를 OpenAI용 벡터로 변환
embeddings = OpenAIEmbeddings()

# FAISS가 벡터를 받아 인덱스를 만들고 빠르게 검색할 수 있도록 준비
vectorstore= FAISS.from_documents(texts, embeddings)

# %%
vectorstore.index.ntotal
# Out:
# 14

# %%
# 검색 설정
retriever = vectorstore.as_retriever(search_kwargs={'k':2}) # 유사도가 가장 높은 문서 2개만 가져오도록

# %%
data = retriever.invoke('스마트 팜 현장지원센터란?')    # 질문을 벡터로 임베딩 -> FAISS 검색 -> 가장 가까운 2개의 문서 변환
data
# Out:
# [Document(id='fd0fff93-bd02-47a3-89ba-2527514edd86', metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='Q. 스마트농업, 스마트팜 정의가 궁금합니다.'),
#  Document(id='ab3d3ec2-0d01-4476-a088-d07bbef760a2', metadata={'source': 'https://www.rda.go.kr/webzine/2022/12/sub1-7.html', 'title': '그린매거진', 'language': 'ko'}, page_content='Q. 우리나라 스마트팜 기술은 어느 수준인가요?')]

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough # 질문을 텍스트 그대로 넘기기

def format_docs(docs):
    return '\n\n'.join(doc.page_content for doc in docs)

# 프롬프트 생성
prompt = PromptTemplate.from_template(
    '''당신은 친절한 질의응답 도우미입니다.
    다음 검색된 맥락을 사용하여 질문에 답하세요.
    답을 모르면 모른다고 말하세요.
    한국어로 답하세요.
    
    #Question: {question}
    #Context: {context}
    #Answer:'''
)

# 모델(LLM)을 생성합니다.
llm = ChatOpenAI(model='gpt-4.1-mini', temperature=0)

# 체인(chain) 생성
chain = (
    {
        'context':retriever | format_docs, 'question':RunnablePassthrough()
    }
    | prompt
    | llm
    | StrOutputParser()
    )

# %%
result = chain.invoke('대표적인 우리나라 스마트농업 기술')

print(result)
# Out:
# 대표적인 우리나라 스마트농업 기술로는 스마트팜이 있습니다. 스마트팜은 ICT(정보통신기술)를 활용해 농작물의 생육 환경을 자동으로 제어하고 관리하는 기술로, 농업 현장의 어려움을 줄이고 생산성을 높이는 데 기여하고 있습니다. 이를 통해 우리나라는 세계적인 경쟁력을 갖추고 있습니다.

# %% [markdown]
# # TTS
# - Text-to-Speech
# - 글자를 사람이 말한 것으로 바꾸는 기술

# %%
# uv add gTTS

from gtts import gTTS
from IPython.display import Audio

text = '안녕하세요. 집에 가고 싶으세요?'
tts = gTTS(text=text, lang='ko')
tts.save('tts_output.mp3')

# %%
Audio('tts_output.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # STT
# - Speech-to-Text
# - 사람이 말한 것을 글자로 바꾸는 기술

# %%
import shutil

print(shutil.which('ffmpeg'))
print(shutil.which('ffprobe'))
# Out:
# None
# None
